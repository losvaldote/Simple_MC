# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
import planckStyle
import pylab
import numpy as np

#dir_name = '/Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains'
dir_name = '/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/Grad'

params1 = {'backend': 'pdf',
               'axes.labelsize': 20,
               'xtick.labelsize': 20,
               'ytick.labelsize': 20,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, width_inch=10,
                           #, ratio=2,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1, 'max_scatter_points':3000})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(['Grad_Ok_l00_phy_BBAO+SN+HD', 'LCDM_phy_BBAO+SN+HD','Grad_Ok_l00_phy_BBAO+SN+HD'], 
                ['ggama', 'Om', 'h', 'Ok'], 
                legend_labels=['Graduated', 'LCDM'],    
                 plot_3d_with_param='ggama')


for ax in g.subplots[:,0]:
    ax.axvline(0, color='red', ls='--')
#g.export('prueba.pdf')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'ls'
#   s)

# %% [markdown]
# ## Coloreada $\gamma$

# %%
g=plots.getSubplotPlotter(chain_dir = dir_name, width_inch=10,
                           #, ratio=2,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1, 'max_scatter_points':3000})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(['Grad_Ok_l00_phy_BBAO+SN+HD', 'LCDM_phy_BBAO+SN+HD','Grad_Ok_l00_phy_BBAO+SN+HD'], 
                ['ggama', 'Om', 'h', 'Ok'], 
                contour_args=[{'lw':2, 'color':'blue',  'ls':'-'},
                              {'lw':5, 'color':'red', 'ls':'-'},
                              {'lw':2, 'color':'blue',  'ls':'-' }
                              ], filled = False,
                              alphas=[0.5, 0.6, 0.9],
                              legend_labels=['Graduated', 'LCDM'],   
                              line_args=[{'lw':2, 'color':'blue'},
                                         {'lw':2, 'color':'red'},
                                         {'lw':2, 'color':'blue'}],
                              contour_colors=['red', 'blue', 'red'],      
                 plot_3d_with_param ='ggama')


for ax in g.subplots[:,0]:
    ax.axvline(0, color='red', ls='--')
    
for ax in g.subplots[3,:]:    
    ax.axhline(0, color='red',ls='--')


g.export('graduated_ggama.pdf')

# %% [markdown]
# # Mejor ajuste y errores de los parámetros de los diferentes modelos.

# %%
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

# %%
for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
    print i,'\t \t',j,k
# Out:
# Om 	 	0.310042666496896 0.018229773229622468
# Obh2 	 	0.022158727878098687 0.00044855833001281313
# h 	 	0.6741091539785585 0.022876299422806785
# ggama 	 	0.19206153177563798 0.0865133742834044
# Ok 	 	-0.16232787307236776 0.11285333977761905
# DR11LOWZ_like 	 	-0.2505756226784589 0.281891298757205
# DR11CMASS_like 	 	-2.210370335332873 0.802635304092403
# DR11LyaAuto_like 	 	-0.4549890354595687 0.5068952015730182
# DR11LyaCross_like 	 	-1.1824372893917083 0.7287382089866958
# SixdFGS_like 	 	-0.033060275572990815 0.044978700422536703
# MGS_like 	 	-0.835466871307422 0.36901027824353066
# BetouleSN_like 	 	-17.634711558756294 1.1258076832657788
# HD_like 	 	-11.687910880451255 0.6364434168266483
# theory_prior 	 	-0.5209122965229156 0.7387535510398835

# %%
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

# %%
for i,j,k in zip(samples2.paramNames.list(), samples2.means, samples2.sddev):
    print i,'\t \t',j,k
# Out:
# Om 	 	0.2861449087632947 0.010260270157852512
# Obh2 	 	0.02205818477440225 0.000451694567393496
# h 	 	0.6686158004398066 0.009035766187935211
# DR11LOWZ_like 	 	-0.1899769162463922 0.23611854204224972
# DR11CMASS_like 	 	-1.852214795123415 0.5161395498265559
# DR11LyaAuto_like 	 	-1.2457645325180737 0.4003115721737646
# DR11LyaCross_like 	 	-2.363175011316014 0.27187540924870696
# SixdFGS_like 	 	-0.01485433475098054 0.02128421908511548
# MGS_like 	 	-1.1143810481682386 0.36593737231034956
# BetouleSN_like 	 	-16.706226467358604 0.12051396428766972
# HD_like 	 	-11.989191213945427 0.5226952184775662
# theory_prior 	 	-0.48555337497590484 0.6756907523532307

# %%
samples7 = g.sampleAnalyser.samplesForRoot('oLCDM_phy_BBAO+SN+HD')
p7 = samples7.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/Grad/oLCDM_phy_BBAO+SN+HD_1.txt
# Removed 0.1 as burn in

# %%
for i,j,k in zip(samples7.paramNames.list(), samples7.means, samples7.sddev):
    print i,'\t \t',j,k
# Out:
# Ok 	 	0.01973083557442373 0.06617828621536367
# Om 	 	0.2849831488962778 0.012180283735732225
# Obh2 	 	0.02203405853981058 0.0004649195818302369
# h 	 	0.6622513150299538 0.02238244319988035
# DR11LOWZ_like 	 	-0.21019928314824013 0.25066682014366665
# DR11CMASS_like 	 	-1.7973631847158569 0.7261146982892095
# DR11LyaAuto_like 	 	-1.431309323000815 0.6553439198905585
# DR11LyaCross_like 	 	-2.511384087980998 0.5288804282638929
# SixdFGS_like 	 	-0.02073175359306146 0.029284394757795894
# MGS_like 	 	-1.0435805471129695 0.4013565160191519
# BetouleSN_like 	 	-16.815005721942246 0.46581428040088996
# HD_like 	 	-12.135138336781013 0.6479178569301534
# theory_prior 	 	-0.5112187847707712 0.7286866619679552

# %% [markdown]
# ## Coloreada $\Omega_k$

# %%
g=plots.getSubplotPlotter(chain_dir = dir_name, width_inch=10,
                           #, ratio=2,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1, 'max_scatter_points':3000})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(['Grad_Ok_l00_phy_BBAO+SN+HD', 'LCDM_phy_BBAO+SN+HD','Grad_Ok_l00_phy_BBAO+SN+HD'], 
                ['ggama', 'Om', 'h', 'Ok'], 
                contour_args=[{'lw':2, 'color':'blue', 'ls':'-'},
                              {'lw':5, 'color':'red', 'ls':'-'},
                              {'lw':2, 'color':'blue', 'ls':'-'}
                              ], filled = False,
                              alphas=[0.5, 0.6, 0.9],
                              legend_labels=['Graduated', 'LCDM'],   
                              line_args=[{'lw':2, 'color':'blue'},
                                         {'lw':2, 'color':'red'},
                                         {'lw':2, 'color':'blue'}],
                              contour_colors=['red', 'blue', 'red'],      
                 plot_3d_with_param ='Ok')


for ax in g.subplots[:,0]:
    ax.axvline(0, color='red', ls='--')
for ax in g.subplots[3,:]:    
    ax.axhline(0, color='red',ls='--')

g.export('graduated_Ok.pdf')

# %% [markdown]
# ## Calcular el Om$h^2$. Una sola gráfica

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, width_inch=7, 
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 12
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Las lineas abajo son para calcular una rhode, por ahora no seran usadas.
#wdeterm1  = (1.0 + al)**2*(1+z)**3 - 2.*al
#wdesqterm = np.sqrt(-4*al**2 + wdeterm1**2)
#wdeterm2   = ((1.0 + al)**2 - 2)*(1.0 + z)**3
#num = (1- Ode)*(wdeterm2 + wdesqterm)
#den = (1- Ode)*(wdeterm2 - 2*al + wdesqterm - 2*al*np.log(0.5*(wdeterm1 + wdesqterm))) + 2*Ode
#wde = -1 + num/den

#rhode = 1 - p.Obh2/(p.h**2)*(1 - 0.5*(wdeterm1 + wdesqterm) + 
 #                            al*np.log(0.5*(wdeterm1 + wdesqterm))) - p.Obh2/(p.h**2)*(1+z)**3

#Estas lineas son para calcular el Omh2, no es Omega_m 
#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
#samples.addDerived( wde , name='wde', label='w_{DE,0}')
#samples.addDerived( rhode , name='rhode', label='\rho_{DE,0}')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

#Para i=1, j=2
g.plot_2d(['Grad_Ok_l00_phy_BBAO+SN+HD','LCDM_phy_BBAO+SN+HD'], 
          param_pair=['Ok', 'Omh23'],  
          filled=False, 
          legend_labels=False, 
          alphas=[0.8, 0.7], 
          contour_colors=['blue','red'],
          contour_args=[{'lw':1, 'color':'blue', 'ls':'-'}, {'lw':2, 'color':'red', 'ls':'-'}])
g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh23','ggama'], alphas=0.9, color_bar=True)
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh13','ggama'], alphas=0.9, color_bar=True)
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh23','ggama'], alphas=0.9, color_bar=True)

#g.rectangle_plot(['ggama'],['Omh12','Omh13','Omh23'], roots='Grad_Ok_l00_phy_BBAO+SN+HD', filled=True) #, xmarkers=[-2], ymarkers=[0,0,0,0])
#g.plots_1d(['LogT_phy_BBAO+SN+HD'], ['Omh12','Omh13','Omh23'], 
#           legend_labels=False,  markers=[0,0], nx=2)

#g.add_legend(['$Omh^2(z_1;z_3)$'],  colored_text=True,  legend_loc='upper left')
g.export('graduated_Omh2z2z3.pdf')

# %% [markdown]
# ## Calcular el Om$h^2$. Varias gráficas.

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, width_inch=7, 
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 12
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Las lineas abajo son para calcular una rhode, por ahora no seran usadas.
#wdeterm1  = (1.0 + al)**2*(1+z)**3 - 2.*al
#wdesqterm = np.sqrt(-4*al**2 + wdeterm1**2)
#wdeterm2   = ((1.0 + al)**2 - 2)*(1.0 + z)**3
#num = (1- Ode)*(wdeterm2 + wdesqterm)
#den = (1- Ode)*(wdeterm2 - 2*al + wdesqterm - 2*al*np.log(0.5*(wdeterm1 + wdesqterm))) + 2*Ode
#wde = -1 + num/den

#rhode = 1 - p.Obh2/(p.h**2)*(1 - 0.5*(wdeterm1 + wdesqterm) + 
 #                            al*np.log(0.5*(wdeterm1 + wdesqterm))) - p.Obh2/(p.h**2)*(1+z)**3

#Estas lineas son para calcular el Omh2, no es Omega_m 
#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
#samples.addDerived( wde , name='wde', label='w_{DE,0}')
#samples.addDerived( rhode , name='rhode', label='\rho_{DE,0}')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

#Para i=1, j=2
#g.plots_2d(['Grad_Ok_l00_phy_BBAO+SN+HD','LCDM_phy_BBAO+SN+HD'], 
g.plots_2d(['Grad_Ok_l00_phy_BBAO+SN+HD'], 
          param_pairs=[['Ok', 'Omh12'], ['Ok', 'Omh13'], ['Ok', 'Omh23']],  
          filled=False, 
          legend_labels=False, 
          alphas=[0.8, 0.7], 
          #contour_colors=['blue','red'],
          contour_colors=['blue'],
          contour_args=[{'lw':1, 'color':'blue', 'ls':'-'}, {'lw':2, 'color':'red', 'ls':'-'}],
          plot_3d_with_param ='ggama', nx=3)
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh12','ggama'], alphas=0.9, color_bar=True)
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh13','ggama'], alphas=0.9, color_bar=True)
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh23','ggama'], alphas=0.9, color_bar=True)

#g.rectangle_plot(['ggama'],['Omh12','Omh13','Omh23'], roots='Grad_Ok_l00_phy_BBAO+SN+HD', filled=True) #, xmarkers=[-2], ymarkers=[0,0,0,0])
#g.plots_1d(['LogT_phy_BBAO+SN+HD'], ['Omh12','Omh13','Omh23'], 
#           legend_labels=False,  markers=[0,0], nx=2)

#g.add_legend(['$Omh^2(z_1;z_3)$'],  colored_text=True,  legend_loc='upper left')
#g.export('Omh2z2z3.pdf')
# Out:
# (3, 1)

# %% [markdown]
# ## Vamos a probar con plots_3d y plots_2d.

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=5,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 20
g.settings.lab_fontsize = 15
g.settings.colorbar_axes_fontsize=15
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 12
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Las lineas abajo son para calcular una rhode, por ahora no seran usadas.
#wdeterm1  = (1.0 + al)**2*(1+z)**3 - 2.*al
#wdesqterm = np.sqrt(-4*al**2 + wdeterm1**2)
#wdeterm2   = ((1.0 + al)**2 - 2)*(1.0 + z)**3
#num = (1- Ode)*(wdeterm2 + wdesqterm)
#den = (1- Ode)*(wdeterm2 - 2*al + wdesqterm - 2*al*np.log(0.5*(wdeterm1 + wdesqterm))) + 2*Ode
#wde = -1 + num/den

#rhode = 1 - p.Obh2/(p.h**2)*(1 - 0.5*(wdeterm1 + wdesqterm) + 
 #                            al*np.log(0.5*(wdeterm1 + wdesqterm))) - p.Obh2/(p.h**2)*(1+z)**3

#Estas lineas son para calcular el Omh2, no es Omega_m 
#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
#samples.addDerived( wde , name='wde', label='w_{DE,0}')
#samples.addDerived( rhode , name='rhode', label='\rho_{DE,0}')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

#Para i=1, j=2
#g.plot_2d(['Grad_Ok_l00_phy_BBAO+SN+HD','LCDM_phy_BBAO+SN+HD'], 
#          param_pair=['Ok', 'Omh12'],  
#          filled=False, 
#          legend_labels=False, 
#          alphas=[0.8, 0.7], 
#          contour_colors=['blue','red'],
#          contour_args=[{'lw':1, 'color':'blue', 'ls':'-'}, {'lw':2, 'color':'red', 'ls':'-'}])
g.plots_2d(['Grad_Ok_l00_phy_BBAO+SN+HD'], 
          param_pairs=[['Ok', 'Omh12'], ['Ok', 'Omh13'], ['Ok', 'Omh23']],  
          filled=False, 
          legend_labels=False, 
          alphas=[0.8, 0.7], 
          #contour_colors=['blue','red'],
          contour_colors=['blue'],
          contour_args=[{'lw':1, 'color':'blue', 'ls':'-'}, {'lw':2, 'color':'red', 'ls':'-'}], nx= 3)
g.plots_3d(['Grad_Ok_l00_phy_BBAO+SN+HD','Grad_Ok_l00_phy_BBAO+SN+HD'],  [['Ok','Omh12','ggama'], ['Ok','Omh13','ggama'], ['Ok','Omh23','ggama']],
           filled = False,
           contour_colors=['blue', 'blue'],
           contour_args=[{'lw':1, 'color':'blue', 'ls':'-'},{'lw':1, 'color':'blue', 'ls':'-'}],
           color_bar=True, nx=3)

#g.export('prueba_varias.pdf')
# Out:
# (3, 1)

# %% [markdown]
# ## Vamos a probar con rectangle plots

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, width_inch=7, subplot_size=6,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 12
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Las lineas abajo son para calcular una rhode, por ahora no seran usadas.
#wdeterm1  = (1.0 + al)**2*(1+z)**3 - 2.*al
#wdesqterm = np.sqrt(-4*al**2 + wdeterm1**2)
#wdeterm2   = ((1.0 + al)**2 - 2)*(1.0 + z)**3
#num = (1- Ode)*(wdeterm2 + wdesqterm)
#den = (1- Ode)*(wdeterm2 - 2*al + wdesqterm - 2*al*np.log(0.5*(wdeterm1 + wdesqterm))) + 2*Ode
#wde = -1 + num/den

#rhode = 1 - p.Obh2/(p.h**2)*(1 - 0.5*(wdeterm1 + wdesqterm) + 
 #                            al*np.log(0.5*(wdeterm1 + wdesqterm))) - p.Obh2/(p.h**2)*(1+z)**3

#Estas lineas son para calcular el Omh2, no es Omega_m 
#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
#samples.addDerived( wde , name='wde', label='w_{DE,0}')
#samples.addDerived( rhode , name='rhode', label='\rho_{DE,0}')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

#Para i=1, j=2
#g.plot_2d(['Grad_Ok_l00_phy_BBAO+SN+HD','LCDM_phy_BBAO+SN+HD'], 
#          param_pair=['Ok', 'Omh23'],  
#          filled=False, 
#          legend_labels=False, 
#          alphas=[0.8, 0.7], 
#          contour_colors=['blue','red'],
#          contour_args=[{'lw':1, 'color':'blue', 'ls':'-'}, {'lw':2, 'color':'red', 'ls':'-'}])
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh23','ggama'], alphas=0.9, color_bar=True)
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh13','ggama'], alphas=0.9, color_bar=True)
#g.plot_3d(['Grad_Ok_l00_phy_BBAO+SN+HD'],  ['Ok','Omh23','ggama'], alphas=0.9, color_bar=True)

g.rectangle_plot(['Omh12','Omh13','Omh23'], ['Ok'], roots='Grad_Ok_l00_phy_BBAO+SN+HD', filled=False, nx=3,
                plot_3d_with_param ='ggama') #, xmarkers=[-2], ymarkers=[0,0,0,0])
#g.plots_1d(['LogT_phy_BBAO+SN+HD'], ['Omh12','Omh13','Omh23'], 
#           legend_labels=False,  markers=[0,0], nx=2)

#g.add_legend(['$Omh^2(z_1;z_3)$'],  colored_text=True,  legend_loc='upper left')
#g.export('graduated_Omh2z2z3.pdf')
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot at 0x7f1e61279090>],
# ...

# %% [markdown]
# ## Otra prueba usando plots_3d. (Este sí funcionó)

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=11,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

g.plots_3d(['Grad_Ok_l00_phy_BBAO+SN+HD','Grad_Ok_l00_phy_BBAO+SN+HD'],  [['Ok','Omh12','ggama'], ['Ok','Omh13','ggama'], ['Ok','Omh23','ggama']],
           filled = False,
           contour_colors=['blue', 'blue'],
           contour_args=[{'lw':1, 'color':'blue', 'ls':'-'},{'lw':1, 'color':'blue', 'ls':'-'}],
           color_bar=True, nx=3)

g.export('graduated_Ok_Omh2_zs_ggama.pdf')

# %% [markdown]
# ## 3d plots con h en el eje x y coloreado con $\gamma$. Se incluyen los valores de $\Lambda$CDM.

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=10,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

g.plots_3d(['Grad_Ok_l00_phy_BBAO+SN+HD','Grad_Ok_l00_phy_BBAO+SN+HD', 'LCDM_phy_BBAO+SN+HD'],
           [['h','Omh12','ggama'], ['h','Omh13','ggama'], ['h','Omh23','ggama']],
           filled = False,
           contour_colors=['blue', 'red'],#Solo se ponen dos porque las regiones de comfianza las pone a partir del segundo archivo.
           contour_args=[{'lw':1, 'color':'blue', 'ls':'-'},{'lw':1, 'color':'red', 'ls':'-'}],
           color_bar=True, nx=3)

g.export('graduated_h_Omh2_zs_ggama.pdf')

# %% [markdown]
# ## 3d plots con h en el eje x y coloreado con Ok. Se incluyen los valores de $\Lambda$CDM.

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=11,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

g.plots_3d(['Grad_Ok_l00_phy_BBAO+SN+HD','Grad_Ok_l00_phy_BBAO+SN+HD', 'LCDM_phy_BBAO+SN+HD'],
           [['h','Omh12','Ok'], ['h','Omh13','Ok'], ['h','Omh23','Ok']],
           filled = False,
           contour_colors=['blue', 'red'],#Solo se ponen dos porque las regiones de comfianza las pone a partir del segundo archivo.
           contour_args=[{'lw':1, 'color':'blue', 'ls':'-'},{'lw':1, 'color':'red', 'ls':'-'}],
           color_bar=True, nx=3)

g.export('graduated_LCDM_h_Omh2_zs_Ok.pdf')

# %% [markdown]
# ## Vamos a obtener la $\chi^2$.

# %%
samples3 = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p3 = samples3.getParams()
print samples3.likeStats
# Out:
# Best fit sample -log(Like) = 32.279000
# Ln(mean 1/like) = 40.276008
# mean(-Ln(like)) = 34.810434
# -Ln(mean like)  = 34.000019
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.1355200E-01  2.7061700E-01  3.5559900E-01  2.5425600E-01  3.7179100E-01   \Omega_m
# Obh2                2.2164700E-02  2.0960100E-02  2.3114500E-02  2.0547200E-02  2.3537300E-02   \Omega_bh^2
# h                   6.7737200E-01  6.2483900E-01  7.3254600E-01  6.0494200E-01  7.4821000E-01   h
# ggama               2.1398800E-01 -3.4215400E-02  3.6267700E-01 -1.6864400E-01  4.1710600E-01   \gamma
# Ok                 -1.9261500E-01 -4.3299400E-01  9.0574300E-02 -5.1465400E-01  2.1244200E-01   \Omega_k
# DR11LOWZ_like      -1.7150800E-01 -1.2095600E+00 -2.6873600E-08 -1.8908500E+00 -1.1704300E-10   DR11LOWZ
# DR11CMASS_like     -1.8993600E+00 -4.4869400E+00 -7.7327800E-01 -6.4841700E+00 -4.0133800E-01   DR11CMASS
# ...

# %%
samples4 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
p4 = samples4.getParams()
print samples4.likeStats
# Out:
# Best fit sample -log(Like) = 34.493700
# Ln(mean 1/like) = 38.191144
# mean(-Ln(like)) = 35.961337
# -Ln(mean like)  = 35.508585
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.8579500E-01  2.6791700E-01  3.0591800E-01  2.5911500E-01  3.1610100E-01   \Omega_m
# Obh2                2.2034800E-02  2.1205800E-02  2.2854300E-02  2.0787600E-02  2.3298900E-02   \Omega_bh^2
# h                   6.6778600E-01  6.5196300E-01  6.8429600E-01  6.4361600E-01  6.9269400E-01   h
# DR11LOWZ_like      -1.0283100E-01 -8.0417200E-01 -1.7380200E-09 -1.3883900E+00 -5.9828400E-10   DR11LOWZ
# DR11CMASS_like     -1.5282700E+00 -2.8617800E+00 -1.2536400E+00 -4.3513200E+00 -1.1361200E+00   DR11CMASS
# DR11LyaAuto_like   -1.1575700E+00 -2.0796900E+00 -6.5052600E-01 -2.6559500E+00 -5.1458600E-01   DR11LyaAuto
# DR11LyaCross_like  -2.3287800E+00 -2.9373800E+00 -1.9207500E+00 -3.3452700E+00 -1.7610700E+00   DR11LyaCross
# ...

# %%
samples5 = g.sampleAnalyser.samplesForRoot('oLCDM_phy_BBAO+SN+HD')
p5 = samples5.getParams()
print samples5.likeStats
# Out:
# Best fit sample -log(Like) = 34.479500
# Ln(mean 1/like) = 40.111130
# mean(-Ln(like)) = 36.475931
# -Ln(mean like)  = 35.857842
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Ok                  2.2020700E-02 -1.1947200E-01  1.6382000E-01 -1.7532500E-01  2.3178100E-01   \Omega_k
# Om                  2.8475600E-01  2.5885600E-01  3.1080500E-01  2.4834100E-01  3.2262900E-01   \Omega_m*
# Obh2                2.2044500E-02  2.1061400E-02  2.3023500E-02  2.0653500E-02  2.3425900E-02   \Omega_bh^2
# h                   6.6256100E-01  6.1556900E-01  7.1171800E-01  5.9595200E-01  7.3211600E-01   h
# DR11LOWZ_like      -9.1240300E-02 -1.0021400E+00 -1.0507800E-10 -1.6013700E+00 -1.0507800E-10   DR11LOWZ
# DR11CMASS_like     -1.3726400E+00 -3.3384500E+00 -5.4191500E-01 -5.1419800E+00 -2.9875200E-01   DR11CMASS
# DR11LyaAuto_like   -1.4101500E+00 -3.0469400E+00 -3.0570400E-01 -3.9532200E+00 -1.1272200E-01   DR11LyaAuto
# ...

# %% [markdown]
# ## Vamos aprobar cómo obtener el promedio de los Omh2. (Sí funcionó)

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=10,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
#samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+SN+HD')
#p2 = samples2.getParams()

#oLCDM model
samples2 = g.sampleAnalyser.samplesForRoot('oLCDM_phy_BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

#Para graduated.
#for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
#    print i,'\t \t',j,k
    
#Para LCDM.
for i,j,k in zip(samples2.paramNames.list(), samples2.means, samples2.sddev):
    print i,'\t \t',j,k
# Out:
# Ok 	 	0.01973083557442373 0.06617828621536367
# Om 	 	0.2849831488962778 0.012180283735732225
# Obh2 	 	0.02203405853981058 0.0004649195818302369
# h 	 	0.6622513150299538 0.02238244319988035
# DR11LOWZ_like 	 	-0.21019928314824013 0.25066682014366665
# DR11CMASS_like 	 	-1.7973631847158569 0.7261146982892095
# DR11LyaAuto_like 	 	-1.431309323000815 0.6553439198905585
# DR11LyaCross_like 	 	-2.511384087980998 0.5288804282638929
# SixdFGS_like 	 	-0.02073175359306146 0.029284394757795894
# MGS_like 	 	-1.0435805471129695 0.4013565160191519
# BetouleSN_like 	 	-16.815005721942246 0.46581428040088996
# HD_like 	 	-12.135138336781013 0.6479178569301534
# theory_prior 	 	-0.5112187847707712 0.7286866619679552
# Omh12 	 	0.12529442720464554 0.011899087438814805
# Omh13 	 	0.12529442720464554 0.011899087438814805
# Omh23 	 	0.12529442720464554 0.011899087438814805
