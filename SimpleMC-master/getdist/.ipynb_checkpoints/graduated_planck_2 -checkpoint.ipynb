# %% [markdown]
# # En este notebook se estudian graduated DE con los datos de Planck 15, BBAO, SN y HD.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
import planckStyle
import pylab
import numpy as np

#dir_name = '/Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains'
dir_name = '/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/Grad_Planck'

params1 = {'backend': 'pdf',
               'axes.labelsize': 20,
               'xtick.labelsize': 20,
               'ytick.labelsize': 20,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %% [markdown]
# ## Coloreada $\gamma$

# %%
g=plots.getSubplotPlotter(chain_dir = dir_name, width_inch=12,
                           #, ratio=2,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1, 'max_scatter_points':3000})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(['Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD', 'LCDM_phy_Planck_15+BBAO+SN+HD','Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD'], 
                ['ggama', 'Om', 'h', 'Ok'], 
                contour_args=[{'lw':2, 'color':'blue',  'ls':'-'},
                              {'lw':5, 'color':'red', 'ls':'-'},
                              {'lw':2, 'color':'blue',  'ls':'-' }
                              ], filled = False,
                              alphas=[0.5, 0.6, 0.9],
                              legend_labels=['Graduated', 'LCDM'],   
                              line_args=[{'lw':2, 'color':'blue'},
                                         {'lw':2, 'color':'red'},
                                         {'lw':2, 'color':'blue'}],
                              contour_colors=['red', 'blue', 'red'],      
                 plot_3d_with_param ='ggama')


for ax in g.subplots[:,0]:
    ax.axvline(0, color='red', ls='--')
    
for ax in g.subplots[3,:]:    
    ax.axhline(0, color='red',ls='--')


#g.export('graduated_Planck_15+BBAO+SN+HD_ggama.pdf')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'lw', 'ls'
#   s)

# %% [markdown]
# # Medias y errores de los parámetros de los diferentes modelos.

# %%
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD')
p = samples.getParams()

# %%
for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
    print i,'\t \t',j,k
# Out:
# Om 	 	0.3016096583950944 0.008714275771936607
# Obh2 	 	0.022488637708267565 0.0001708062731475679
# h 	 	0.6814140630300733 0.009766882596835126
# ggama 	 	0.003928803262299607 0.047424594257928644
# Ok 	 	-0.0027949326433200864 0.0023597272144553795
# SPlanck_15_like 	 	-1.6730644877343608 1.3368652851543237
# DR11LOWZ_like 	 	-0.2623599939880065 0.28405877401865065
# DR11CMASS_like 	 	-1.670439741979911 0.5620997678440545
# DR11LyaAuto_like 	 	-1.930899107522828 0.3262822023286683
# DR11LyaCross_like 	 	-2.202238814205868 0.18132645086430227
# SixdFGS_like 	 	-0.021327008146818698 0.02986811696225717
# MGS_like 	 	-0.9301455072203085 0.3675171956964884
# BetouleSN_like 	 	-16.90335685459211 0.3960254163833686
# HD_like 	 	-13.086826668396643 0.44872442705748605

# %%
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
p2 = samples2.getParams()

# %%
for i,j,k in zip(samples2.paramNames.list(), samples2.means, samples2.sddev):
    print i,'\t \t',j,k
# Out:
# Om 	 	0.3021040215626139 0.006380065963523573
# Obh2 	 	0.02244239200519427 0.00014783081814731351
# h 	 	0.6817153741457994 0.0049102670003544945
# SPlanck_15_like 	 	-1.2951643511310644 1.082511130927196
# DR11LOWZ_like 	 	-0.18763080729815518 0.18392910251502656
# DR11CMASS_like 	 	-1.4624453729104145 0.3230807876854547
# DR11LyaAuto_like 	 	-2.144389881796657 0.07954191949377559
# DR11LyaCross_like 	 	-2.1805335547405207 0.11915554646180439
# SixdFGS_like 	 	-0.010342345785902655 0.014201501948859656
# MGS_like 	 	-0.9507126023854537 0.26676715032375337
# BetouleSN_like 	 	-16.63677031898433 0.03801422362570483
# HD_like 	 	-13.360206276283225 0.3635791884324204

# %%
samples7 = g.sampleAnalyser.samplesForRoot('oLCDM_phy_Planck_15+BBAO+SN+HD')
p = samples7.getParams()

# %%
for i,j,k in zip(samples7.paramNames.list(), samples7.means, samples7.sddev):
    print i,'\t \t',j,k
# Out:
# Ok 	 	-0.000687288760255873 0.002031645025037767
# Om 	 	0.3026209288681209 0.006787928781567813
# Obh2 	 	0.02247537215351191 0.00017548208594212857
# h 	 	0.6802479856134063 0.006967735825427959
# SPlanck_15_like 	 	-1.6732462292843642 1.3162248963772398
# DR11LOWZ_like 	 	-0.2768598308851806 0.29397133840927836
# DR11CMASS_like 	 	-1.6020888678313543 0.48327043997553853
# DR11LyaAuto_like 	 	-2.0784217683025137 0.22466471264654153
# DR11LyaCross_like 	 	-2.2148120889957816 0.14710935337117698
# SixdFGS_like 	 	-0.017498169814124682 0.023971257200062164
# MGS_like 	 	-0.9002178196900186 0.3297262307092318
# BetouleSN_like 	 	-16.641431685547634 0.04293219067535793
# HD_like 	 	-13.28797267893416 0.43346475992951533

# %% [markdown]
# ## Coloreada $\Omega_k$

# %%
g=plots.getSubplotPlotter(chain_dir = dir_name, width_inch=12,
                           #, ratio=2,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1, 'max_scatter_points':3000})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(['Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD', 'LCDM_phy_Planck_15+BBAO+SN+HD','Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD'], 
                ['ggama', 'Om', 'h', 'Ok'], 
                contour_args=[{'lw':2, 'color':'blue', 'ls':'-'},
                              {'lw':5, 'color':'red', 'ls':'-'},
                              {'lw':2, 'color':'blue', 'ls':'-'}
                              ], filled = False,
                              alphas=[0.5, 0.6, 0.9],
                              legend_labels=['Graduated', 'LCDM'],   
                              line_args=[{'lw':2, 'color':'blue'},
                                         {'lw':2, 'color':'red'},
                                         {'lw':2, 'color':'blue'}],
                              contour_colors=['red', 'blue', 'red'],      
                 plot_3d_with_param ='Ok')


for ax in g.subplots[:,0]:
    ax.axvline(0, color='red', ls='--')
for ax in g.subplots[3,:]:    
    ax.axhline(0, color='red',ls='--')

g.export('graduated_Planck_15+BBAO+SN+HD_Ok.pdf')

# %% [markdown]
# ## Otra prueba usando plots_3d. (Este sí funcionó)

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=12,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

g.plots_3d(['Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD','Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD'],  [['Ok','Omh12','ggama'], ['Ok','Omh13','ggama'], ['Ok','Omh23','ggama']],
           filled = False,
           contour_colors=['blue', 'blue'],
           contour_args=[{'lw':1, 'color':'blue', 'ls':'-'},{'lw':1, 'color':'blue', 'ls':'-'}],
           color_bar=True, nx=3)

g.export('graduated_Planck_15+BBAO+SN+HD_Ok_Omh2_zs_ggama.pdf')
# Out:
# WARNING:root:outlier fraction 9.24641701341e-05

# %% [markdown]
# ## 3d plots con h en el eje x y coloreado con $\gamma$. Se incluyen los valores de $\Lambda$CDM.

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=11,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

g.plots_3d(['Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD','Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD', 'LCDM_phy_Planck_15+BBAO+SN+HD'],
           [['h','Omh12','ggama'], ['h','Omh13','ggama'], ['h','Omh23','ggama']],
           filled = False,
           contour_colors=['blue', 'red'],#Solo se ponen dos porque las regiones de comfianza las pone a partir del segundo archivo.
           contour_args=[{'lw':1, 'color':'blue', 'ls':'-'},{'lw':1, 'color':'red', 'ls':'-'}],
           color_bar=True, nx=3)

g.export('graduated_LCDM_Planck_15+BBAO+SN+HD_h_Omh2_zs_ggama.pdf')
# Out:
# WARNING:root:outlier fraction 9.24641701341e-05

# %% [markdown]
# ## 3d plots con h en el eje x y coloreado con Ok. Se incluyen los valores de $\Lambda$CDM.

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=11,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

g.plots_3d(['Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD','Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD', 'LCDM_phy_Planck_15+BBAO+SN+HD'],
           [['h','Omh12','Ok'], ['h','Omh13','Ok'], ['h','Omh23','Ok']],
           filled = False,
           contour_colors=['blue', 'red'],#Solo se ponen dos porque las regiones de comfianza las pone a partir del segundo archivo.
           contour_args=[{'lw':1, 'color':'blue', 'ls':'-'},{'lw':1, 'color':'red', 'ls':'-'}],
           color_bar=True, nx=3)

g.export('graduated_LCDM_Planck_15+BBAO+SN+HD_h_Omh2_zs_Ok.pdf')
# Out:
# WARNING:root:outlier fraction 9.24641701341e-05

# %% [markdown]
# ## Vamos a obtener la $\chi^2$.

# %%
samples3 = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD')
p3 = samples3.getParams()
print samples3.likeStats
# Out:
# Best fit sample -log(Like) = 36.341100
# Ln(mean 1/like) = 42.973034
# mean(-Ln(like)) = 38.680659
# -Ln(mean like)  = 37.948051
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0040000E-01  2.8109400E-01  3.2356800E-01  2.7376800E-01  3.3199300E-01   \Omega_m
# Obh2                2.2486800E-02  2.2083900E-02  2.2858800E-02  2.1932300E-02  2.3014100E-02   \Omega_bh^2
# h                   6.8193100E-01  6.5809800E-01  7.0591100E-01  6.5136800E-01  7.1408000E-01   h
# ggama              -4.5259100E-03 -1.0998700E-01  1.2212600E-01 -1.4354500E-01  1.5485700E-01   \gamma
# Ok                 -3.3692300E-03 -8.0858700E-03  2.9269300E-03 -9.9145800E-03  4.9598900E-03   \Omega_k
# SPlanck_15_like    -3.3820700E-01 -4.0822600E+00 -2.2800100E-03 -6.5957500E+00 -2.2800100E-03   SPlanck_15
# DR11LOWZ_like      -1.7645000E-01 -1.2601000E+00 -5.8652100E-08 -1.9753300E+00 -4.7008800E-10   DR11LOWZ
# DR11CMASS_like     -1.3565500E+00 -3.3557400E+00 -7.7047900E-01 -4.7916800E+00 -6.2516500E-01   DR11CMASS
# DR11LyaAuto_like   -1.8201200E+00 -2.7709600E+00 -1.2825100E+00 -3.2123900E+00 -1.1207900E+00   DR11LyaAuto
# DR11LyaCross_like  -2.2046500E+00 -2.6605400E+00 -1.8190800E+00 -2.9183400E+00 -1.7514400E+00   DR11LyaCross
# SixdFGS_like       -2.0070900E-03 -1.4524000E-01 -7.4348100E-10 -2.5871500E-01 -7.1267700E-11   SixdFGS
# MGS_like           -9.1867000E-01 -1.9063200E+00 -2.0762200E-01 -2.3412200E+00 -6.7911600E-02   MGS
# BetouleSN_like     -1.6632800E+01 -1.8472000E+01 -1.6535800E+01 -1.9986200E+01 -1.6509900E+01   BetouleSN
# HD_like            -1.2891700E+01 -1.4298100E+01 -1.2215300E+01 -1.5116200E+01 -1.1979700E+01   HD
# Omh12*              1.3819759E-01  1.2138391E-01  1.5771894E-01  1.1380662E-01  1.6276140E-01   Omh^2(z_1;z_2)
# Omh13*              1.3910853E-01  1.3458903E-01  1.4476920E-01  1.3269714E-01  1.4689260E-01   Omh^2(z_1;z_3)
# Omh23*              1.3918682E-01  1.3553383E-01  1.4401129E-01  1.3375663E-01  1.4571242E-01   Omh^2(z_2;z_3)

# %%
samples4 = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
p4 = samples4.getParams()
print samples4.likeStats
# Out:
# Best fit sample -log(Like) = 36.721500
# Ln(mean 1/like) = 41.419309
# mean(-Ln(like)) = 38.228195
# -Ln(mean like)  = 37.769374
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0168300E-01  2.9013600E-01  3.1381600E-01  2.8470600E-01  3.1991300E-01   \Omega_m*
# Obh2                2.2443800E-02  2.2167000E-02  2.2719100E-02  2.2043500E-02  2.2848100E-02   \Omega_bh^2
# h                   6.8195500E-01  6.7283000E-01  6.9105700E-01  6.6828800E-01  6.9550700E-01   h
# SPlanck_15_like    -7.8624300E-02 -1.9960800E+00 -2.8661900E-03 -4.1430400E+00 -2.8661900E-03   SPlanck_15
# DR11LOWZ_like      -1.2450000E-01 -6.1661600E-01 -1.6286500E-08 -9.8699300E-01 -1.7164600E-09   DR11LOWZ
# DR11CMASS_like     -1.3119100E+00 -2.3199000E+00 -1.2124400E+00 -3.2036600E+00 -1.2081300E+00   DR11CMASS
# DR11LyaAuto_like   -2.1406500E+00 -2.2871700E+00 -1.9945800E+00 -2.3627200E+00 -1.9207500E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1748400E+00 -2.3935400E+00 -1.9506900E+00 -2.4955900E+00 -1.8471600E+00   DR11LyaCross
# SixdFGS_like       -1.3737400E-03 -4.4204800E-02 -6.3471500E-11 -8.6775300E-02 -6.3471500E-11   SixdFGS
# MGS_like           -9.5214500E-01 -1.4920600E+00 -5.0175200E-01 -1.7699300E+00 -3.2839300E-01   MGS
# BetouleSN_like     -1.6617500E+01 -1.6730700E+01 -1.6607200E+01 -1.6833300E+01 -1.6607200E+01   BetouleSN
# HD_like            -1.3319900E+01 -1.4063900E+01 -1.2717300E+01 -1.4448600E+01 -1.2457600E+01   HD
# Omh12*              1.4030149E-01  1.3847274E-01  1.4220873E-01  1.3754077E-01  1.4311768E-01   Omh2
# Omh13*              1.4030149E-01  1.3847274E-01  1.4220873E-01  1.3754077E-01  1.4311768E-01   Omh2
# Omh23*              1.4030149E-01  1.3847274E-01  1.4220873E-01  1.3754077E-01  1.4311768E-01   Omh2

# %%
samples5 = g.sampleAnalyser.samplesForRoot('oLCDM_phy_Planck_15+BBAO+SN+HD')
p5 = samples5.getParams()
print samples5.likeStats
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/Grad_Planck/oLCDM_phy_Planck_15+BBAO+SN+HD_1.txt
# Removed 0.1 as burn in
# Best fit sample -log(Like) = 36.674100
# Ln(mean 1/like) = 42.564750
# mean(-Ln(like)) = 38.692549
# -Ln(mean like)  = 38.076802
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Ok                 -8.1376400E-04 -5.0338300E-03  3.6319500E-03 -6.7465000E-03  5.4200000E-03   \Omega_k
# Om                  3.0343700E-01  2.8846700E-01  3.1729800E-01  2.8258400E-01  3.2364700E-01   \Omega_m*
# Obh2                2.2469700E-02  2.2106400E-02  2.2840600E-02  2.1954300E-02  2.2989400E-02   \Omega_bh^2
# h                   6.7933800E-01  6.6560200E-01  6.9551300E-01  6.5976000E-01  7.0181700E-01   h
# SPlanck_15_like    -1.6852300E-01 -3.5722000E+00 -2.4391100E-03 -6.2283500E+00 -2.4391100E-03   SPlanck_15
# DR11LOWZ_like      -2.1643000E-01 -1.1730700E+00 -3.2575900E-10 -1.8501300E+00 -3.2575900E-10   DR11LOWZ
# DR11CMASS_like     -1.2602700E+00 -3.0946500E+00 -1.1476200E+00 -4.6525200E+00 -1.1016500E+00   DR11CMASS
# DR11LyaAuto_like   -2.0663600E+00 -2.5798700E+00 -1.6281000E+00 -2.7980100E+00 -1.4661600E+00   DR11LyaAuto
# DR11LyaCross_like  -2.2222700E+00 -2.5264000E+00 -1.8989800E+00 -2.6974100E+00 -1.7921600E+00   DR11LyaCross
# SixdFGS_like       -6.0240100E-03 -9.7459700E-02 -4.7622800E-11 -1.7129400E-01 -4.6934800E-13   SixdFGS
# MGS_like           -8.3427800E-01 -1.6906200E+00 -2.9040600E-01 -2.0307800E+00 -1.3717100E-01   MGS
# BetouleSN_like     -1.6627300E+01 -1.6780700E+01 -1.6594200E+01 -1.6898900E+01 -1.6588500E+01   BetouleSN
# HD_like            -1.3272600E+01 -1.4277000E+01 -1.2435500E+01 -1.4782600E+01 -1.2165400E+01   HD

# %% [markdown]
# ## Vamos aprobar cómo obtener el promedio de los Omh2. (Sí funcionó)

# %%
g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=10,
                          analysis_settings={'smooth_scale_1D': 0.8, 'ignore_rows': 0.1,  'max_scatter_points':3000})
samples = g.sampleAnalyser.samplesForRoot('Grad_Ok_l00_phy_Planck_15+BBAO+SN+HD')
p = samples.getParams()

g.settings.axes_fontsize = 28
g.settings.lab_fontsize = 28
g.settings.colorbar_axes_fontsize=25
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 15
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'

z1= 0.0
z2 = 0.57
z3 = 2.34

zrho_0 = 0
z=zrho_0

#al = p.alpha
Ode = 1 - p.Om - p.Ok

#Este termino es el mismo siempre
term1 = p.h**2*p.Om

#Para i=1, j=2
term122 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z2))/((1.+z1)**3 - (1.+z2)**3))
term123 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z2)**2)/((1.+z1)**3 - (1.+z2)**3))

#Para i=1, j=3
term132 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z1)/(1.+z3))/((1.+z1)**3 - (1.+z3)**3))
term133 = p.h**2*p.Ok*(((1.+z1)**2 - (1.+z3)**2)/((1.+z1)**3 - (1.+z3)**3))

#Para i=2, j=3
term232 = 3.*p.ggama*p.h**2*Ode*(np.log((1.+z2)/(1.+z3))/((1.+z2)**3 - (1.+z3)**3))
term233 = p.h**2*p.Ok*(((1.+z2)**2 - (1.+z3)**2)/((1.+z2)**3 - (1.+z3)**3))


Omh12 = term1 + term122 + term123

Omh13 = term1 + term132 + term133

Omh23 = term1 + term232 + term233
        


samples.addDerived( Omh12 , name='Omh12', label='Omh^2(z_1;z_2)')
samples.addDerived( Omh13 , name='Omh13', label='Omh^2(z_1;z_3)')
samples.addDerived( Omh23 , name='Omh23', label='Omh^2(z_2;z_3)')
samples.updateBaseStatistics()

#LCDM model
#samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
#p2 = samples2.getParams()

#oLCDM model
samples2 = g.sampleAnalyser.samplesForRoot('oLCDM_phy_Planck_15+BBAO+SN+HD')
p2 = samples2.getParams()

Omh12 =p2.h**2*p2.Om
samples2.addDerived( Omh12 , name='Omh12', label='Omh2')
Omh13 =p2.h**2*p2.Om
samples2.addDerived( Omh13 , name='Omh13', label='Omh2')
Omh23 =p2.h**2*p2.Om
samples2.addDerived( Omh23 , name='Omh23', label='Omh2')
samples2.updateBaseStatistics()

#Para graduated.
#for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
#    print i,'\t \t',j,k
    
#Para LCDM y oLCDM.
for i,j,k in zip(samples2.paramNames.list(), samples2.means, samples2.sddev):
    print i,'\t \t',j,k
# Out:
# WARNING:root:outlier fraction 9.24641701341e-05
# Ok 	 	-0.000687288760255873 0.002031645025037767
# Om 	 	0.3026209288681209 0.006787928781567813
# Obh2 	 	0.02247537215351191 0.00017548208594212857
# h 	 	0.6802479856134063 0.006967735825427959
# SPlanck_15_like 	 	-1.6732462292843642 1.3162248963772398
# DR11LOWZ_like 	 	-0.2768598308851806 0.29397133840927836
# DR11CMASS_like 	 	-1.6020888678313543 0.48327043997553853
# DR11LyaAuto_like 	 	-2.0784217683025137 0.22466471264654153
# DR11LyaCross_like 	 	-2.2148120889957816 0.14710935337117698
# SixdFGS_like 	 	-0.017498169814124682 0.023971257200062164
# MGS_like 	 	-0.9002178196900186 0.3297262307092318
# BetouleSN_like 	 	-16.641431685547634 0.04293219067535793
# HD_like 	 	-13.28797267893416 0.43346475992951533
# Omh12 	 	0.13999135839412594 0.0014266130627218266
# Omh13 	 	0.13999135839412594 0.0014266130627218266
# Omh23 	 	0.13999135839412594 0.0014266130627218266
