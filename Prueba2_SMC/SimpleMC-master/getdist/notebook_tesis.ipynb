# %% [markdown]
# # Notebook para la tesis.
# ## En este notebook se pondrán sólo las partes necesarias del notebook dr12_constraints para la tesis.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots
import planckStyle
import pylab
import numpy as np

#dir_name = '/Users/josevazquezgonzalez/Desktop/BOSS/BOSS_files/DR12/chains'
#dir_name = '/home/osbuster/Documentos/Prueba_SMC/SimpleMC-master/chains'
dir_name = '/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains'

params1 = {'backend': 'pdf',
               'axes.labelsize': 20,
               'xtick.labelsize': 20,
               'ytick.labelsize': 20,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
#roots = ['EKCDM1_phy_BBAO+Planck+SN']
roots = ['wDM_phy_BBAO+Planck+SN']
#roots = ['owaCDM_phy_BBAO', 'owaCDM_phy_BBAO+Planck', 'owaCDM_phy_BBAO+Planck+SN']

g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','w', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
#
#Varias graficas.
#g.plot_2d(roots, param_pair=['w','Om'], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN'], colored_text=True,  legend_loc='upper right')
g.export('wMO_w_EKCDM1_BBAO_Planck_SN.pdf')

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['EKCDM2_phy_BBAO+Planck+SN']
#roots = ['owaCDM_phy_BBAO', 'owaCDM_phy_BBAO+Planck', 'owaCDM_phy_BBAO+Planck+SN']

g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','w', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
#
#Varias graficas.
#g.plot_2d(roots, param_pair=['w','Om'], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN'], colored_text=True,  legend_loc='upper right')
g.export('wMO_w_EKCDM2_BBAO_Planck_SN.pdf')

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['EKCDM2_phy_BBAO+Planck+SN']
#roots = ['owaCDM_phy_BBAO', 'owaCDM_phy_BBAO+Planck', 'owaCDM_phy_BBAO+Planck+SN']

g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','wa', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
g.add_y_marker(0, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
#
#Varias graficas.
#g.plot_2d(roots, param_pair=['w','Om'], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN'], colored_text=True,  legend_loc='upper right')
g.export('wMO_wa_EKCDM2_BBAO_Planck_SN.pdf')

# %%
roots = ['EKCDM2_phy_BBAO+Planck+SN']
g= plots.getSinglePlotter(chain_dir = dir_name)
g.settings.axes_fontsize = 12
#g.plot_3d(roots, 'wMO', 'w', 'wa')
g.plot_3d(roots, ['wMO','w','wa'])
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
g.export('wMO_w_wa_EKCDM2_BBAO_Planck_SN.pdf')

# %%
roots = ['EKCDM2_phy_BBAO+Planck+SN']

g = plots.getSubplotPlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.2})
g.settings.axes_fontsize = 12
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.triangle_plot(roots, params=['wMO','w','wa'], filled=True)
#g.plot_2d(roots, 'Afs8','Bfs8', filled=True, legend_labels=False, colors = ['blue'], alphas=[0.8])
g.add_legend(['BBAO+Planck+SN'], colored_text=True,  legend_loc='upper right')


#g.export('Afs8_degene.pdf')

# %%
#roots = ['mnu_Afs8_PLK+DR12+ALLB']
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']
#roots = ['EKCDM2_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 20
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
g.add_x_marker(1)
g.plot_1d(roots, 'wMO', legend_labels=False, colors = ['green', 'gray', 'red', 'blue'])
g.add_legend([  'wMO',
             ], 
               legend_loc='upper right')
#g.export('Afs8_mnu.pdf')

# %%
#roots = ['mnu_Afs8_PLK+DR12+ALLB']
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']
#roots = ['EKCDM2_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.0} )
g.settings.axes_fontsize = 20
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
g.add_x_marker(1)
g.plot_1d(roots, 'wMO', legend_labels=False, colors = ['green', 'gray', 'red', 'blue'])
g.add_legend([  'wMO',
             ], 
               legend_loc='upper right')
#Las líneas siguientes son para obtener una tabla con los datos del mejor ajuste.
samples = g.sampleAnalyser.samplesForRoot('Early_DE_DM1_phy_BBAO+Planck+SN')
#samples = g.sampleAnalyser.samplesForRoot('EKCDM2_phy_BBAO+Planck+SN')
p = samples.getParams()
#g.export('Afs8_mnu.pdf')

# %%
#Datos de mejor ajuste.
print samples.likeStats
# Out:
# Best fit sample -log(Like) = 23.333900
# mean(-Ln(like)) = 26.347926
# -Ln(mean like)  = 25.411305
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0159100E-01  2.7775300E-01  3.3056700E-01  2.6993300E-01  3.3876400E-01   \Omega_m*
# Obh2                2.2568800E-02  2.1627200E-02  2.3397700E-02  2.1386800E-02  2.3653300E-02   \Omega_bh^2
# h                   6.7620500E-01  6.4880600E-01  7.0504100E-01  6.4008300E-01  7.1483800E-01   h
# w                  -9.8176200E-01 -1.2057500E+00 -8.3603600E-01 -1.3209800E+00 -7.8218000E-01   w_0
# Ode                 4.9850700E-03  6.5131100E-07  1.7818500E-01  6.5131100E-07  2.1238300E-01   \Omega^e_{\rm de}
# wMO                 8.3465900E-04 -3.0721200E-02  6.9304200E-03 -3.9240100E-02  8.6850100E-03   w_{MO}
# DR11LOWZ_like      -1.6588800E-01 -1.5392700E+00 -4.4297200E-09 -2.2793700E+00 -4.0720800E-10   DR11LOWZ
# DR11CMASS_like     -1.2089300E+00 -3.9184200E+00 -5.5551600E-01 -5.9835200E+00 -3.7066300E-01   DR11CMASS
# DR11LyaAuto_like   -2.1778100E+00 -4.8113000E+00 -1.6561400E+00 -5.7916800E+00 -1.5021600E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1679900E+00 -2.9627500E+00 -1.7609100E+00 -3.4074400E+00 -1.6493900E+00   DR11LyaCross
# SixdFGS_like       -6.2336800E-03 -2.2585700E-01 -1.9453000E-11 -3.6337800E-01 -1.9453000E-11   SixdFGS
# MGS_like           -8.4518700E-01 -1.9806900E+00 -1.0703300E-01 -2.3875300E+00 -1.8192000E-02   MGS
# SPlanck_like       -1.2146500E-01 -3.8187500E+00 -8.4046900E-04 -6.4456100E+00 -8.4046900E-04   SPlanck
# BetouleSN_like     -1.6640400E+01 -1.9626500E+01 -1.6515200E+01 -2.1660600E+01 -1.6494300E+01   BetouleSN

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-16974c7ed509> in <module>()
# ----> 1 print samples.mean(wMO)
#
# NameError: name 'wMO' is not defined
