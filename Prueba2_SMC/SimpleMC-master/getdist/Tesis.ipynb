# %% [markdown]
# # Notebook 2 para la tesis.
# ## En este notebook se pondrán sólo las partes necesarias del notebook dr12_constraints para la tesis.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots
import planckStyle
import pylab
import numpy as np

#dir_name = '/Users/josevazquezgonzalez/Desktop/BOSS/BOSS_files/DR12/chains'
#dir_name = '/home/osbuster/Documentos/Prueba_SMC/SimpleMC-master/chains'
dir_name = '/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains'

params1 = {'backend': 'pdf',
               'axes.labelsize': 20,
               'xtick.labelsize': 20,
               'ytick.labelsize': 20,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %% [markdown]
# # Modelo wDM

# %%
roots = ['wDM_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
g.add_x_marker(1)
g.plot_1d(roots, 'wDM', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'wDM',
             ], 
               legend_loc='upper right')
g.export('wDM_wDM.pdf')
samples = g.sampleAnalyser.samplesForRoot('wDM_phy_BBAO+Planck+SN')
p = samples.getParams()

# %%
#Datos de mejor ajuste.
print samples.likeStats
# Out:
# Best fit sample -log(Like) = 23.296900
# Ln(mean 1/like) = 28.919332
# mean(-Ln(like)) = 25.280441
# -Ln(mean like)  = 24.674049
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# wDM                 1.6058100E-03 -3.1370400E-03  6.0727800E-03 -4.9960800E-03  8.0865100E-03   w_{DM}
# Om                  3.0148800E-01  2.8448000E-01  3.1855100E-01  2.7776100E-01  3.2643700E-01   \Omega_m*
# Obh2                2.2504200E-02  2.1733000E-02  2.3235600E-02  2.1404300E-02  2.3544200E-02   \Omega_bh^2
# h                   6.7851700E-01  6.6330000E-01  6.9608700E-01  6.5648000E-01  7.0323500E-01   h
# DR11LOWZ_like      -1.9786400E-01 -1.1619400E+00 -1.6888300E-10 -1.8794700E+00 -1.6888300E-10   DR11LOWZ
# DR11CMASS_like     -1.2683100E+00 -3.0740000E+00 -1.1420100E+00 -4.8601700E+00 -1.0960300E+00   DR11CMASS
# DR11LyaAuto_like   -2.0980600E+00 -2.4872700E+00 -1.7513500E+00 -2.6550000E+00 -1.6042500E+00   DR11LyaAuto
# ...

# %%
#Da la desviacion estandar
samples.std(p.wDM), samples.std(p.Om), samples.std(p.Obh2), samples.std(p.h)
# Out:
# (0.002158579275433891,
#  0.008093561865780693,
#  0.0003476027098662315,
#  0.007759825847233769)

# %% [markdown]
# # EKCDMCosmology 1
# ## Se permite variar la ecuación de estado de la materia oscura y el primer parámetro de la CPL de energía oscura.

# %% [markdown]
# ### Parámetro de materia oscura.

# %%
roots = ['EKCDM1_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
g.add_x_marker(1)
g.plot_1d(roots, 'wMO', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'wMO',
             ], 
               legend_loc='upper right')
g.export('wMO_EKCDM1.pdf')
samples2 = g.sampleAnalyser.samplesForRoot('EKCDM1_phy_BBAO+Planck+SN')
p2 = samples2.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/EKCDM1_phy_BBAO+Planck+SN_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples2.likeStats
# Out:
# Best fit sample -log(Like) = 23.233400
# Ln(mean 1/like) = 30.180329
# mean(-Ln(like)) = 25.715604
# -Ln(mean like)  = 24.942240
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0273800E-01  2.8063900E-01  3.2870900E-01  2.7187200E-01  3.3853700E-01   \Omega_m*
# Obh2                2.2502400E-02  2.1675600E-02  2.3315400E-02  2.1332400E-02  2.3646100E-02   \Omega_bh^2
# h                   6.7766700E-01  6.5074300E-01  7.0223300E-01  6.4140100E-01  7.1291100E-01   h
# w                  -9.8162900E-01 -1.1171600E+00 -8.4066000E-01 -1.1688500E+00 -7.9088400E-01   w_0
# wMO                 8.5878700E-04 -4.6163000E-03  6.6675500E-03 -6.9758300E-03  8.9467300E-03   w_{MO}
# DR11LOWZ_like      -1.5527600E-01 -1.3272400E+00 -3.0133300E-09 -2.1318200E+00 -5.4547800E-11   DR11LOWZ
# DR11CMASS_like     -1.2251000E+00 -3.6201800E+00 -5.9360700E-01 -5.6279000E+00 -4.2243300E-01   DR11CMASS
# ...

# %%
samples2.std(p2.wMO), samples2.std(p2.Om), samples2.std(p2.Obh2), samples2.std(p2.h)
# Out:
# (0.002425263221965846,
#  0.010376383763278712,
#  0.0003591591868235429,
#  0.011071697034942795)

# %%
samples2.std(p2.w)
# Out:
# 0.05904240035934595

# %% [markdown]
# ### Parámetro de energía oscura.

# %%
roots = ['EKCDM1_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
g.add_x_marker(1)
g.plot_1d(roots, 'w', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'w',
             ], 
               legend_loc='upper right')
g.export('w0_EKCDM1.pdf')

# %% [markdown]
# ### Correlación entre wMO y w.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['EKCDM1_phy_BBAO+Planck+SN']


g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','w', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
#
#Varias graficas.
#g.plot_2d(roots, param_pair=['w','Om'], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN'], colored_text=True,  legend_loc='upper right')
g.export('wMO_w_EKCDM1.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/EKCDM1_phy_BBAO+Planck+SN_1.txt
# Removed no burn in

# %% [markdown]
# # EKCDMCosmology 2.
# ## En este modelo se permite variar la ecuación de estado de la materia oscura y ambos parámetros en la parametrización CPL para la energía oscura

# %% [markdown]
# ### Parámetro de materia oscura.

# %%
roots = ['EKCDM2_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'wMO', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'wMO',
             ], 
               legend_loc='upper right')
g.export('wMO_EKCDM2.pdf')
samples3 = g.sampleAnalyser.samplesForRoot('EKCDM2_phy_BBAO+Planck+SN')
p3 = samples3.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/EKCDM2_phy_BBAO+Planck+SN_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples3.likeStats
# Out:
# Best fit sample -log(Like) = 23.051000
# mean(-Ln(like)) = 25.761577
# -Ln(mean like)  = 24.944490
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0386700E-01  2.8123800E-01  3.3349100E-01  2.7208900E-01  3.4294800E-01   \Omega_m*
# Obh2                2.2476700E-02  2.1640600E-02  2.3329200E-02  2.1335500E-02  2.3674000E-02   \Omega_bh^2
# h                   6.7495800E-01  6.4720700E-01  7.0290300E-01  6.3885700E-01  7.1347600E-01   h
# w                  -9.2005200E-01 -1.1746600E+00 -5.9297700E-01 -1.2592900E+00 -5.1235600E-01   w_0
# wa                 -4.1858700E-01 -1.9979800E+00  7.8226100E-01 -1.9997600E+00  9.6621500E-01   w_a
# wMO                 3.2899800E-03 -6.4558600E-03  1.0060100E-02 -1.0452900E-02  1.2524800E-02   w_{MO}
# DR11LOWZ_like      -1.4048000E-01 -1.3829700E+00 -1.1396300E-09 -2.0959400E+00 -1.1396300E-09   DR11LOWZ
# ...

# %%
samples3.std(p3.wMO), samples3.std(p3.Om), samples3.std(p3.Obh2), samples3.std(p3.h)
# Out:
# (0.002984100213725573,
#  0.010702570680069984,
#  0.0003487018982087885,
#  0.011345060370438514)

# %%
samples3.std(p3.w)
# Out:
# 0.10922525936073825

# %%
samples3.std(p3.wa)
# Out:
# 0.5456722789640398

# %% [markdown]
# ### Parámetro w0 de energía oscura.

# %%
roots = ['EKCDM2_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'w', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'w',
             ], 
               legend_loc='upper right')
g.export('w0_EKCDM2.pdf')

# %% [markdown]
# ### Parámetro wa de energía oscura.

# %%
roots = ['EKCDM2_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'wa', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'wa',
             ], 
               legend_loc='upper right')
g.export('wa_EKCDM2.pdf.pdf')

# %% [markdown]
# ### Correlación entre wMO y w0.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['EKCDM2_phy_BBAO+Planck+SN']


g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','w', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
#
#Varias graficas.
#g.plot_2d(roots, param_pair=['w','Om'], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN'], colored_text=True,  legend_loc='upper right')
g.export('wMO_w0_EKCDM2.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/EKCDM2_phy_BBAO+Planck+SN_1.txt
# Removed no burn in

# %% [markdown]
# ### Correlación entre wMO y wa.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['EKCDM2_phy_BBAO+Planck+SN']


g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','wa', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
g.add_y_marker(0, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
#
#Varias graficas.
#g.plot_2d(roots, param_pair=['w','Om'], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN'], colored_text=True,  legend_loc='upper right')
#g.export('wMO_w_EKCDM1_BBAO_Planck_SN.pdf')

g.export('wMO_wa_EKCDM2.pdf')

# %% [markdown]
# ### Correlación entre wMO, w0 y wa.

# %%
roots = ['EKCDM2_phy_BBAO+Planck+SN']
g= plots.getSinglePlotter(chain_dir = dir_name)
g.settings.axes_fontsize = 12
#g.plot_3d(roots, 'wMO', 'w', 'wa')
g.plot_3d(roots, ['wMO','w','wa'])
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
g.export('wMO_w_wa_EKCDM2.pdf')

# %% [markdown]
# # Early_DE_DM1

# %% [markdown]
# ### Parámetro wMO para materia oscura.

# %%
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'wMO', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'wMO',
             ], 
               legend_loc='upper right')
g.export('wMO_Early_DE_DM1.pdf')
samples4 = g.sampleAnalyser.samplesForRoot('Early_DE_DM1_phy_BBAO+Planck+SN')
p4 = samples4.getParams()

# %%
#Datos de mejor ajuste.
print samples4.likeStats
# Out:
# Best fit sample -log(Like) = 23.343500
# mean(-Ln(like)) = 26.295776
# -Ln(mean like)  = 25.386301
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0390700E-01  2.7833100E-01  3.3068300E-01  2.7013300E-01  3.4045800E-01   \Omega_m*
# Obh2                2.2365900E-02  2.1585100E-02  2.3432000E-02  2.1325000E-02  2.3724000E-02   \Omega_bh^2
# h                   6.7621200E-01  6.4911600E-01  7.0556100E-01  6.4134500E-01  7.1575300E-01   h
# w                  -9.8012400E-01 -1.2079800E+00 -8.3214300E-01 -1.3130300E+00 -7.9510300E-01   w_0
# Ode                 2.2994100E-03  6.3633900E-06  1.6762000E-01  6.3633900E-06  2.3560700E-01   \Omega^e_{\rm de}
# wMO                 3.5902500E-04 -2.8234800E-02  6.2538500E-03 -4.3355400E-02  8.6581600E-03   w_{MO}
# DR11LOWZ_like      -1.7019200E-01 -1.5826900E+00 -2.2077800E-08 -2.1898800E+00 -4.5384000E-09   DR11LOWZ
# ...

# %%
samples4.std(p4.wMO), samples4.std(p4.Om), samples4.std(p4.Obh2), samples4.std(p4.h)
# Out:
# (0.006480259052203297,
#  0.010419311902288378,
#  0.0003567484902127006,
#  0.011044384395108419)

# %%
samples4.std(p4.w)
# Out:
# 0.07025314304047585

# %%
samples4.std(p4.Ode)
# Out:
# 0.036534851530261314

# %% [markdown]
# ### Parámetro w0 para energía oscura.

# %%
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'w', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'w',
             ], 
               legend_loc='upper right')
g.export('w0_Early_DE_DM1.pdf')

# %% [markdown]
# ### Parámetro de densidad de energía oscura a tiempos tempranos.

# %%
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'Ode', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([  'Ode',
             ], 
               legend_loc='upper right')
g.export('Ode_Early_DE_DM1.pdf')

# %% [markdown]
# ### Correlación entre wMO y w0.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']


g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','w', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
g.export('wMO_w0_Early_DE_DM1.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/Early_DE_DM1_phy_BBAO+Planck+SN_1.txt
# Removed no burn in

# %% [markdown]
# ### Correlación entre wMO y Ode.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']


g= plots.getSinglePlotter(chain_dir = dir_name)
#Una sola grafica
g.plot_2d(roots, 'wMO','Ode', filled=True)
g.add_legend(['BBAO+Planck+SN','dim', 'hh'], colored_text=True,  legend_loc='upper right')
#g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
g.export('wMO_Ode_Early_DE_DM1.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/Early_DE_DM1_phy_BBAO+Planck+SN_1.txt
# Removed no burn in

# %% [markdown]
# ### Correlación entre wMO, w0 y Ode.

# %%
roots = ['Early_DE_DM1_phy_BBAO+Planck+SN']
g= plots.getSinglePlotter(chain_dir = dir_name)
g.settings.axes_fontsize = 12
#g.plot_3d(roots, 'wMO', 'w', 'wa')
g.plot_3d(roots, ['wMO','w','Ode'])
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
g.export('wMO_w_Ode_Early_DE_DM1.pdf')

# %% [markdown]
# # Modelo LCDM

# %%
roots = ['LCDM_phy_BBAO+Planck+SN']
g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples5 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+Planck+SN')
p5 = samples5.getParams()

# %%
#Datos de mejor ajuste.
print samples5.likeStats
# Out:
# Best fit sample -log(Like) = 23.506500
# Ln(mean 1/like) = 29.482787
# mean(-Ln(like)) = 24.999390
# -Ln(mean like)  = 24.541926
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0194700E-01  2.8756800E-01  3.1730000E-01  2.8055500E-01  3.2502600E-01   \Omega_m*
# Obh2                2.2336300E-02  2.1838700E-02  2.2825800E-02  2.1598100E-02  2.3075600E-02   \Omega_bh^2
# h                   6.8219100E-01  6.7019100E-01  6.9402400E-01  6.6445000E-01  7.0017300E-01   h
# DR11LOWZ_like      -1.0865500E-01 -7.6644200E-01 -1.0307700E-10 -1.3029400E+00 -1.0307700E-10   DR11LOWZ
# DR11CMASS_like     -1.3297700E+00 -2.8702500E+00 -1.1889100E+00 -4.2929400E+00 -1.1782200E+00   DR11CMASS
# DR11LyaAuto_like   -2.1999400E+00 -2.3989600E+00 -2.0053000E+00 -2.4967500E+00 -1.9084800E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1662000E+00 -2.4394700E+00 -1.8826800E+00 -2.5670200E+00 -1.7599200E+00   DR11LyaCross
# ...

# %%
samples5.std(p5.Om), samples5.std(p5.Obh2), samples5.std(p5.h)
# Out:
# (0.008029733836310697, 0.00026694997286332467, 0.00642879922514029)
