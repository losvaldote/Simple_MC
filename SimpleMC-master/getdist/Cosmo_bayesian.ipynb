# %% [markdown]
# # Notebook para el artículo cosmología observacional.
# ### En este notebook se elaborarán las gráficas para el artículo de cosmología observacional.
# ### El modelo LCDM es el modelo cosmológico estándar.
# ### El modelo cLCDM es $\Lamda$ CDM donde el parámetro de densidad asociado a la curvatura se ha dejado libre para que sea ajustado por el código SimpleMc.
# #### Está basado en el notebook dr12_constraints.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots
import planckStyle
import pylab
import numpy as np

#dir_name = '/Users/josevazquezgonzalez/Desktop/BOSS/BOSS_files/DR12/chains'
dir_name = '/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains'
#dir_name = '/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/data'

params1 = {'backend': 'pdf',
               'axes.labelsize': 20,
               'xtick.labelsize': 20,
               'ytick.labelsize': 20,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %% [markdown]
# # $\Lambda$DCM.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['LCDM_phy_BBAO', 'LCDM_phy_BBAO+Planck', 'LCDM_phy_BBAO+Planck+SN','LCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Obh2','Om'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
plt.title("$\Lambda$CDM", fontsize = 20)
g.export('Obh2_Om_LCDM_todas.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['LCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['h','Om'], filled=True)
g.add_legend(['BBAO+Planck+SN+HD'], colored_text=True, legend_loc='lower left')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
#
plt.title("$\Lambda$CDM", fontsize = 20)
g.export('h_Om_LCDM_BBAO+Planck+SN+HD.pdf')

# %% [markdown]
# # c$\Lambda$CDM (Con curvatura).

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['cLCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Om','Ok'], filled=True)
#g.add_legend(['BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='lower left')
g.add_y_marker(0, color = 'black', lw= '1') #linea en y
g.add_x_marker(0.299, color = 'black', lw = '1') #linea en x
plt.title("o$\Lambda$CDM", fontsize = 20)
g.export('Om_Ok_cLCDM_BBAO+Planck+SN+HD.pdf')

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['cLCDM_phy_BBAO', 'cLCDM_phy_BBAO+Planck', 'cLCDM_phy_BBAO+Planck+SN','cLCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['h','Om'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper left')
g.export('h_Om_cLCDM_todas.pdf')

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['cLCDM_phy_BBAO', 'cLCDM_phy_BBAO+Planck', 'cLCDM_phy_BBAO+Planck+SN','cLCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Ok','Om'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
g.export('Ok_Om_cLCDM_todas.pdf')

# %% [markdown]
# # owaCDM (Cold Dark Matter más Parametrización CPL)

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['owaCDM_phy_BBAO', 'owaCDM_phy_BBAO+Planck', 'owaCDM_phy_BBAO+Planck+SN','owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Obh2','Om'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
g.export('Obh2_Om_owaCDM_todas.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck+SN_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['owaCDM_phy_BBAO', 'owaCDM_phy_BBAO+Planck', 'owaCDM_phy_BBAO+Planck+SN','owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['h','Om'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
g.export('h_Om_owaCDM_todas.pdf')

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['owaCDM_phy_BBAO', 'owaCDM_phy_BBAO+Planck', 'owaCDM_phy_BBAO+Planck+SN','owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Ok','Om'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
g.export('Ok_Om_owaCDM_todas.pdf')

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['owaCDM_phy_BBAO', 'owaCDM_phy_BBAO+Planck', 'owaCDM_phy_BBAO+Planck+SN','owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['w','wa'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
g.export('w0_wa_owaCDM_todas.pdf')

# %% [markdown]
# # En esta sección se obtendrán los valores de mejor ajuste para cada modelo y así hacer la tabla para el artículo de Cosmología Observacional.

# %% [markdown]
# # $\Lambda$CDM BAO

# %%
roots = ['LCDM_phy_BBAO']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO')
p = samples.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples.likeStats
# Out:
# Best fit sample -log(Like) = 6.190240
# Ln(mean 1/like) = 11.179364
# mean(-Ln(like)) = 7.707922
# -Ln(mean like)  = 7.235530
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.8512900E-01  2.5337700E-01  3.2603000E-01  2.3923400E-01  3.5049400E-01   \Omega_m*
# Obh2                2.2037600E-02  2.1155900E-02  2.2886100E-02  2.0743900E-02  2.3311100E-02   \Omega_bh^2
# h                   6.6578700E-01  6.4284200E-01  6.9158100E-01  6.3158400E-01  7.0458300E-01   h
# DR11LOWZ_like      -1.2986700E-01 -9.8373800E-01 -2.9599600E-09 -1.7004100E+00 -2.9599600E-09   DR11LOWZ
# DR11CMASS_like     -1.5402100E+00 -2.9680100E+00 -9.7394600E-01 -4.5385200E+00 -7.1155900E-01   DR11CMASS
# DR11LyaAuto_like   -1.0884300E+00 -3.5355900E+00 -4.8490100E-01 -5.2411300E+00 -4.0417800E-01   DR11LyaAuto
# DR11LyaCross_like  -2.3875000E+00 -3.7736700E+00 -1.9219300E+00 -4.9651200E+00 -1.7484900E+00   DR11LyaCross
# ...

# %%
#Da la desviacion estandar
samples.std(p.Om), samples.std(p.Obh2), samples.std(p.h)
# Out:
# (0.019937829283623136, 0.00046073934838553314, 0.013058375716755315)

# %% [markdown]
# # $\Lambda$CDM BBAO+Planck

# %%
roots = ['LCDM_phy_BBAO+Planck']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples2 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+Planck')
p2 = samples2.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples2.likeStats
# Out:
# Best fit sample -log(Like) = 6.885540
# Ln(mean 1/like) = 11.305448
# mean(-Ln(like)) = 8.384445
# -Ln(mean like)  = 7.929488
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0245300E-01  2.8747400E-01  3.1813000E-01  2.8022200E-01  3.2579700E-01   \Omega_m*
# Obh2                2.2337700E-02  2.1829800E-02  2.2829300E-02  2.1592900E-02  2.3076000E-02   \Omega_bh^2
# h                   6.8180500E-01  6.6963900E-01  6.9419300E-01  6.6384400E-01  7.0025300E-01   h
# DR11LOWZ_like      -1.2227900E-01 -8.1764500E-01 -2.7892900E-11 -1.3817100E+00 -2.7892900E-11   DR11LOWZ
# DR11CMASS_like     -1.3068400E+00 -2.8647300E+00 -1.1890000E+00 -4.3796900E+00 -1.1788600E+00   DR11CMASS
# DR11LyaAuto_like   -2.2029200E+00 -2.4083000E+00 -2.0030200E+00 -2.5099700E+00 -1.9018700E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1763400E+00 -2.4534500E+00 -1.8830300E+00 -2.5828900E+00 -1.7547300E+00   DR11LyaCross
# ...

# %%
#Da la desviacion estandar
samples2.std(p.Om), samples2.std(p2.Obh2), samples2.std(p2.h)
# Out:
# (0.030963973194087786, 0.00026935483686126374, 0.006628554234736485)

# %% [markdown]
# # $\Lambda$ CDM BBAO+Planck+SN

# %%
roots = ['LCDM_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples3 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+Planck+SN')
p3 = samples3.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples3.likeStats
# Out:
# Best fit sample -log(Like) = 23.506500
# Ln(mean 1/like) = 29.482787
# mean(-Ln(like)) = 24.999390
# -Ln(mean like)  = 24.541926
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0194700E-01  2.8756800E-01  3.1730000E-01  2.8055500E-01  3.2502600E-01   \Omega_m*
# Obh2                2.2336300E-02  2.1838700E-02  2.2825800E-02  2.1598100E-02  2.3075600E-02   \Omega_bh^2
# h                   6.8219100E-01  6.7019100E-01  6.9402400E-01  6.6445000E-01  7.0017300E-01   h
# DR11LOWZ_like      -1.0865500E-01 -7.6644200E-01 -1.0307700E-10 -1.3029400E+00 -1.0307700E-10   DR11LOWZ
# DR11CMASS_like     -1.3297700E+00 -2.8702500E+00 -1.1889100E+00 -4.2929400E+00 -1.1782200E+00   DR11CMASS
# DR11LyaAuto_like   -2.1999400E+00 -2.3989600E+00 -2.0053000E+00 -2.4967500E+00 -1.9084800E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1662000E+00 -2.4394700E+00 -1.8826800E+00 -2.5670200E+00 -1.7599200E+00   DR11LyaCross
# ...

# %%
#Da la desviacion estandar
samples3.std(p3.Om), samples3.std(p3.Obh2), samples3.std(p3.h)
# Out:
# (0.008029733836310697, 0.00026694997286332467, 0.00642879922514029)

# %% [markdown]
# # $\Lambda$ CDM BBAO+Planck+SN+HD

# %%
roots = ['LCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples4 = g.sampleAnalyser.samplesForRoot('LCDM_phy_BBAO+Planck+SN+HD')
p4 = samples4.getParams()

# %%
#Datos de mejor ajuste.
print samples4.likeStats
# Out:
# Best fit sample -log(Like) = 36.785500
# Ln(mean 1/like) = 42.535729
# mean(-Ln(like)) = 38.286984
# -Ln(mean like)  = 37.831794
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.9880500E-01  2.8468400E-01  3.1331600E-01  2.7783300E-01  3.2109000E-01   \Omega_m*
# Obh2                2.2365300E-02  2.1862600E-02  2.2854600E-02  2.1618000E-02  2.3102300E-02   \Omega_bh^2
# h                   6.8445300E-01  6.7277000E-01  6.9632200E-01  6.6705300E-01  7.0215600E-01   h
# DR11LOWZ_like      -4.6755600E-02 -5.4272600E-01 -1.6293300E-10 -1.0149700E+00 -1.6293300E-10   DR11LOWZ
# DR11CMASS_like     -1.5078400E+00 -3.3888900E+00 -1.1921300E+00 -4.9791400E+00 -1.1805400E+00   DR11CMASS
# DR11LyaAuto_like   -2.1608700E+00 -2.3536000E+00 -1.9678800E+00 -2.4530800E+00 -1.8722400E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1072500E+00 -2.3714500E+00 -1.8277200E+00 -2.5032300E+00 -1.7175900E+00   DR11LyaCross
# ...

# %%
#Da la desviacion estandar
samples4.std(p4.Om), samples4.std(p4.Obh2), samples4.std(p4.h)
# Out:
# (0.0078015018007825294, 0.0002656931549384967, 0.006329519513505223)

# %% [markdown]
# # c$\Lambda$CDM BBAO

# %%
roots = ['cLCDM_phy_BBAO']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples5 = g.sampleAnalyser.samplesForRoot('cLCDM_phy_BBAO')
p5 = samples5.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples5.likeStats
# Out:
# Best fit sample -log(Like) = 6.044510
# Ln(mean 1/like) = 11.430678
# mean(-Ln(like)) = 8.060977
# -Ln(mean like)  = 7.445775
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.9811100E-01  2.1868500E-01  3.5218300E-01  1.4604700E-01  3.7609300E-01   \Omega_m*
# Obh2                2.1978600E-02  2.1053600E-02  2.2989900E-02  2.0651100E-02  2.3401400E-02   \Omega_bh^2
# h                   6.9717600E-01  5.4261300E-01  7.9769000E-01  4.0631400E-01  8.3088900E-01   h
# Ok                 -8.1058700E-02 -3.1139500E-01  3.2359800E-01 -3.5457400E-01  6.5263900E-01   \Omega_k
# DR11LOWZ_like      -9.6175900E-02 -1.1183600E+00 -1.7761900E-09 -1.8943400E+00 -1.3778600E-12   DR11LOWZ
# DR11CMASS_like     -2.1852900E+00 -5.3653900E+00 -2.4349600E-01 -6.9919500E+00 -2.9449400E-04   DR11CMASS
# DR11LyaAuto_like   -8.3382000E-01 -3.8446700E+00 -2.0650700E-03 -5.6320300E+00 -1.5401700E-03   DR11LyaAuto
# ...

# %%
#Da la desviacion estandar
samples5.std(p5.Om), samples5.std(p5.Obh2), samples5.std(p5.h), samples5.std(p5.Ok)
# Out:
# (0.03232347976928085,
#  0.0004557224540494443,
#  0.06024123542785797,
#  0.15232536969129606)

# %% [markdown]
# # c$\Lambda$CDM BBAO+Planck

# %%
roots = ['cLCDM_phy_BBAO+Planck']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples6 = g.sampleAnalyser.samplesForRoot('cLCDM_phy_BBAO+Planck')
p6 = samples6.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO+Planck_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples6.likeStats
# Out:
# Best fit sample -log(Like) = 6.514670
# Ln(mean 1/like) = 12.402567
# mean(-Ln(like)) = 8.488107
# -Ln(mean like)  = 7.870898
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0142800E-01  2.8335300E-01  3.1924300E-01  2.7617100E-01  3.2722200E-01   \Omega_m*
# Obh2                2.2480800E-02  2.1789900E-02  2.3266700E-02  2.1467100E-02  2.3580600E-02   \Omega_bh^2
# h                   6.7818800E-01  6.6377800E-01  6.9475900E-01  6.5722000E-01  7.0149800E-01   h
# Ok                 -2.6624600E-03 -9.2010400E-03  3.9495400E-03 -1.1979200E-02  6.7587400E-03   \Omega_k
# DR11LOWZ_like      -2.2123500E-01 -1.2651800E+00 -2.6726500E-09 -2.0055900E+00 -5.8862900E-10   DR11LOWZ
# DR11CMASS_like     -1.3098800E+00 -3.0098300E+00 -1.1009700E+00 -4.6705700E+00 -1.0143000E+00   DR11CMASS
# DR11LyaAuto_like   -1.8828900E+00 -2.7504200E+00 -1.1651700E+00 -3.1610700E+00 -9.3229600E-01   DR11LyaAuto
# ...

# %%
#Da la desviacion estandar
samples6.std(p6.Om), samples6.std(p6.Obh2), samples6.std(p6.h), samples6.std(p6.Ok)
# Out:
# (0.008343622706436104,
#  0.0003457746359894926,
#  0.007269596566177062,
#  0.0030775717012964834)

# %% [markdown]
# # c$\Lambda$CDM BBAO+Planck+SN

# %%
roots = ['cLCDM_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples7 = g.sampleAnalyser.samplesForRoot('cLCDM_phy_BBAO+Planck+SN')
p7 = samples7.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO+Planck+SN_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples7.likeStats
# Out:
# Best fit sample -log(Like) = 23.127700
# Ln(mean 1/like) = 28.691984
# mean(-Ln(like)) = 25.117520
# -Ln(mean like)  = 24.504874
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0035400E-01  2.8380700E-01  3.1834400E-01  2.7655900E-01  3.2576400E-01   \Omega_m*
# Obh2                2.2504100E-02  2.1782600E-02  2.3250200E-02  2.1479800E-02  2.3560600E-02   \Omega_bh^2
# h                   6.7918600E-01  6.6405000E-01  6.9458400E-01  6.5765500E-01  7.0162000E-01   h
# Ok                 -2.5958900E-03 -9.2158900E-03  3.9310900E-03 -1.1751200E-02  6.6965900E-03   \Omega_k
# DR11LOWZ_like      -1.8299900E-01 -1.2128100E+00 -2.3557400E-08 -1.8955800E+00 -4.7583100E-11   DR11LOWZ
# DR11CMASS_like     -1.3194600E+00 -2.9382900E+00 -1.1036100E+00 -4.6508700E+00 -1.0172800E+00   DR11CMASS
# DR11LyaAuto_like   -1.8767200E+00 -2.7464100E+00 -1.1739800E+00 -3.1682000E+00 -9.4424400E-01   DR11LyaAuto
# ...

# %%
#Da la desviacion estandar
samples7.std(p7.Om), samples7.std(p7.Obh2), samples7.std(p7.h), samples7.std(p7.Ok)
# Out:
# (0.00812223308304047,
#  0.000339487042127963,
#  0.0072085719351010795,
#  0.0030570663139762406)

# %% [markdown]
# # c$\Lambda$CDM BBAO+Planck+SN+HD

# %%
roots = ['cLCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples8 = g.sampleAnalyser.samplesForRoot('cLCDM_phy_BBAO+Planck+SN+HD')
p8 = samples8.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples8.likeStats
# Out:
# Best fit sample -log(Like) = 35.796300
# Ln(mean 1/like) = 41.835145
# mean(-Ln(like)) = 37.775346
# -Ln(mean like)  = 37.163099
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.9769900E-01  2.8073200E-01  3.1392200E-01  2.7418000E-01  3.2131000E-01   \Omega_m*
# Obh2                2.2665700E-02  2.1951900E-02  2.3367500E-02  2.1647700E-02  2.3647900E-02   \Omega_bh^2
# h                   6.7892100E-01  6.6462700E-01  6.9473700E-01  6.5853100E-01  7.0130000E-01   h
# Ok                 -4.1416100E-03 -9.9199300E-03  1.9902500E-03 -1.2564700E-02  4.7007600E-03   \Omega_k
# DR11LOWZ_like      -1.8108800E-01 -1.0976900E+00 -4.4420600E-10 -1.7622800E+00 -4.1256300E-11   DR11LOWZ
# DR11CMASS_like     -1.3746300E+00 -3.1281900E+00 -1.1797200E+00 -4.8105200E+00 -1.0970500E+00   DR11CMASS
# DR11LyaAuto_like   -1.6792100E+00 -2.4595800E+00 -1.0765900E+00 -2.8381300E+00 -8.7756500E-01   DR11LyaAuto
# ...

# %%
#Da la desviacion estandar
samples8.std(p8.Om), samples8.std(p8.Obh2), samples8.std(p8.h), samples8.std(p8.Ok)
# Out:
# (0.007803547529768933,
#  0.000331724732939175,
#  0.0071206983713108865,
#  0.002856727592161261)

# %% [markdown]
# # owaCDM BBAO

# %%
roots = ['owaCDM_phy_BBAO']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples9 = g.sampleAnalyser.samplesForRoot('owaCDM_phy_BBAO')
p9 = samples9.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples9.likeStats
# Out:
# Best fit sample -log(Like) = 2.455960
# mean(-Ln(like)) = 5.145362
# -Ln(mean like)  = 4.283897
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  1.9825000E-01  9.9270500E-02  5.3776700E-01  9.9270500E-02  5.7161800E-01   \Omega_m*
# Obh2                2.2142400E-02  2.0872400E-02  2.3165200E-02  2.0507400E-02  2.3549500E-02   \Omega_bh^2
# h                   4.7845300E-01  4.0121800E-01  7.6022700E-01  4.0003100E-01  7.9357700E-01   h
# w                  -5.4916900E-01 -1.0288900E+00 -1.4248500E-02 -1.2796700E+00 -7.8970600E-04   w_0
# wa                  2.3058100E-01 -1.9999200E+00  9.5898200E-01 -1.9999800E+00  1.4393000E+00   w_a
# Ok                 -2.4558900E-01 -6.7275900E-01  1.5250600E-01 -8.4559700E-01  3.8188700E-01   \Omega_k
# DR11LOWZ_like      -7.9309400E-01 -2.8836400E+00 -7.8542300E-09 -4.4083400E+00 -1.8007900E-09   DR11LOWZ
# ...

# %%
#Da la desviacion estandar
samples9.std(p9.Om), samples9.std(p9.Obh2), samples9.std(p9.h), samples9.std(p9.w), samples9.std(p9.wa),samples9.std(p9.Ok)
# Out:
# (0.07613927256688352,
#  0.00046369167116602474,
#  0.06988565302953988,
#  0.19920873027590108,
#  0.7000283598014597,
#  0.17292939247642308)

# %% [markdown]
# # owaCDM BBAO+Planck

# %%
roots = ['owaCDM_phy_BBAO+Planck']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples10 = g.sampleAnalyser.samplesForRoot('owaCDM_phy_BBAO+Planck')
p10 = samples10.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples10.likeStats
# Out:
# Best fit sample -log(Like) = 4.866950
# Ln(mean 1/like) = 11.917094
# mean(-Ln(like)) = 7.630110
# -Ln(mean like)  = 6.769978
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.6544400E-01  2.7949400E-01  4.0308200E-01  2.5314800E-01  4.2607900E-01   \Omega_m*
# Obh2                2.2513300E-02  2.1678100E-02  2.3376500E-02  2.1374800E-02  2.3688700E-02   \Omega_bh^2
# h                   6.1638300E-01  5.8384800E-01  7.0291800E-01  5.6985100E-01  7.4057000E-01   h
# w                  -3.0887000E-01 -1.1887400E+00 -7.8294800E-02 -1.5003000E+00 -1.6997900E-02   w_0
# wa                 -1.8234200E+00 -1.9998500E+00  6.1698200E-01 -1.9998500E+00  1.3018600E+00   w_a
# Ok                 -3.5985600E-03 -1.4769800E-02  8.8051900E-03 -1.7978800E-02  1.3989800E-02   \Omega_k
# DR11LOWZ_like      -4.6844300E-01 -2.2218500E+00 -2.7788100E-09 -3.4424200E+00 -2.7788100E-09   DR11LOWZ
# ...

# %%
#Da la desviacion estandar
samples10.std(p10.Om), samples10.std(p10.Obh2), samples10.std(p10.h), samples10.std(p10.w), samples10.std(p10.wa),samples10.std(p10.Ok)
# Out:
# (0.023268425624380477,
#  0.0003519403272978343,
#  0.022792386832637724,
#  0.20162727002701727,
#  0.5418786103490528,
#  0.004525152515726348)

# %% [markdown]
# # owaCDM BBAO+Planck+SN

# %%
roots = ['owaCDM_phy_BBAO+Planck+SN']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples11 = g.sampleAnalyser.samplesForRoot('owaCDM_phy_BBAO+Planck+SN')
p11 = samples11.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck+SN_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples11.likeStats
# Out:
# Best fit sample -log(Like) = 22.734100
# mean(-Ln(like)) = 25.736327
# -Ln(mean like)  = 24.836713
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0707000E-01  2.7887400E-01  3.3417300E-01  2.7093300E-01  3.4328300E-01   \Omega_m*
# Obh2                2.2477400E-02  2.1632700E-02  2.3421100E-02  2.1304100E-02  2.3665400E-02   \Omega_bh^2
# h                   6.7145400E-01  6.4471400E-01  7.0327100E-01  6.3649900E-01  7.1388300E-01   h
# w                  -8.8418600E-01 -1.1817300E+00 -5.7705700E-01 -1.2670500E+00 -4.8156600E-01   w_0
# wa                 -4.9048200E-01 -1.9985400E+00  7.8072000E-01 -1.9991500E+00  1.1088600E+00   w_a
# Ok                 -4.9984500E-03 -1.3974700E-02  7.6314200E-03 -1.7203600E-02  1.3319200E-02   \Omega_k
# DR11LOWZ_like      -1.7285500E-01 -1.4585600E+00 -1.2108200E-09 -2.1468800E+00 -1.2108200E-09   DR11LOWZ
# ...

# %%
#Da la desviacion estandar
samples11.std(p11.Om), samples11.std(p11.Obh2), samples11.std(p11.h), samples11.std(p11.w), samples11.std(p11.wa),samples11.std(p11.Ok)
# Out:
# (0.010860381861606523,
#  0.0003514564827970505,
#  0.011547530708703044,
#  0.12929731605759506,
#  0.6304608648692753,
#  0.004312843141758061)

# %% [markdown]
# # owaCDM BBAO+Planck+SN+HD

# %%
roots = ['owaCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples12 = g.sampleAnalyser.samplesForRoot('owaCDM_phy_BBAO+Planck+SN+HD')
p12 = samples12.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples12.likeStats
# Out:
# Best fit sample -log(Like) = 34.840500
# Ln(mean 1/like) = 42.775734
# mean(-Ln(like)) = 37.800551
# -Ln(mean like)  = 36.879901
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0619100E-01  2.7898800E-01  3.3330400E-01  2.6935700E-01  3.4275700E-01   \Omega_m*
# Obh2                2.2633800E-02  2.1723300E-02  2.3446900E-02  2.1454500E-02  2.3761400E-02   \Omega_bh^2
# h                   6.7003400E-01  6.4449400E-01  7.0058800E-01  6.3548700E-01  7.1151200E-01   h
# w                  -8.6309100E-01 -1.1166300E+00 -5.5023400E-01 -1.2013400E+00 -4.7687000E-01   w_0
# wa                 -5.2863600E-01 -1.9979700E+00  4.0021300E-01 -1.9998800E+00  7.6130700E-01   w_a
# Ok                 -5.9608800E-03 -1.4167800E-02  2.4703200E-03 -1.6818500E-02  5.5716000E-03   \Omega_k
# DR11LOWZ_like      -1.4339900E-01 -1.2586700E+00 -1.0837300E-11 -1.8018300E+00 -1.0837300E-11   DR11LOWZ
# ...

# %%
#Da la desviacion estandar
samples12.std(p12.Om), samples12.std(p12.Obh2), samples12.std(p12.h), samples12.std(p12.w), samples12.std(p12.wa),samples12.std(p12.Ok)
# Out:
# (0.010763838500255883,
#  0.0003410645923368654,
#  0.011304843722743887,
#  0.1134803407200201,
#  0.5150364981971012,
#  0.0033424220424508886)

# %% [markdown]
# # En esta sección se graficarán los parámetros en común que tienen los modelos $\Lambda$CDM, o$\Lambda$CDM y owaCDM usando los datos de BAO+Planck+SN+HD.
#
# ## Los tres modelos tienen en común los parámetros $\Omega_m$, $\Omega_b h^2$ y $h$. Además compararemos la densidad de curvatura para los modelos que la tienen.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['LCDM_phy_BBAO+Planck+SN+HD','cLCDM_phy_BBAO+Planck+SN+HD','owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Obh2','Om'], filled=True)
g.add_legend(['$\Lambda$CDM', 'c$\Lambda$CDM', 'owaCDM'], colored_text=True,  legend_loc='upper right')
#g.export('Obh2_Om_LCDM_todas.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['LCDM_phy_BBAO+Planck+SN+HD','cLCDM_phy_BBAO+Planck+SN+HD','owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['h','Om'], filled=True)
g.add_legend(['$\Lambda$CDM', 'c$\Lambda$CDM', 'owaCDM'], colored_text=True,  legend_loc='upper right')
#g.export('Obh2_Om_LCDM_todas.pdf')

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['cLCDM_phy_BBAO+Planck+SN+HD','owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Ok','Om'], filled=True)
g.add_legend(['c$\Lambda$CDM', 'owaCDM'], colored_text=True,  legend_loc='upper right')
#g.export('Obh2_Om_LCDM_todas.pdf')

# %% [markdown]
# ## Ahora obtendremos las gráficas del mejor ajuste de los parámetros en los tres modelos usando todos los datos observacionales.

# %%
roots = ['LCDM_phy_BBAO+Planck+SN+HD','cLCDM_phy_BBAO+Planck+SN+HD','owaCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'Om', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([ '$\Lambda$CDM', 'c$\Lambda$CDM', 'owaCDM'], 
               legend_loc='upper right')
g.export('Om_best_fit.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in

# %%
roots = ['LCDM_phy_BBAO+Planck+SN+HD','cLCDM_phy_BBAO+Planck+SN+HD','owaCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'Obh2', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([ '$\Lambda$CDM', 'c$\Lambda$CDM', 'owaCDM'], 
               legend_loc='upper right')
g.export('Obh2_best_fit.pdf')

# %%
roots = ['LCDM_phy_BBAO+Planck+SN+HD','cLCDM_phy_BBAO+Planck+SN+HD','owaCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'h', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([ '$\Lambda$CDM', 'c$\Lambda$CDM', 'owaCDM'], 
               legend_loc='upper right')
g.export('h_best_fit.pdf')

# %%
roots = ['cLCDM_phy_BBAO+Planck+SN+HD','owaCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 25
g.settings.alpha_filled_add =0.9
g.settings.legend_fontsize = 18
g.settings.legend_frame = False
#g.add_x_marker(1)
g.plot_1d(roots, 'Ok', legend_labels=False, colors = ['black', 'gray', 'red', 'blue'])
g.add_legend([ 'c$\Lambda$CDM', 'owaCDM'], 
               legend_loc='upper right')
g.export('Ok_best_fit.pdf')

# %% [markdown]
# ## En esta sección haré las gráficas finales para el artículo según el ejemplo que me mandó el Doc Beto.

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['LCDM_phy_BBAO', 'LCDM_phy_BBAO+Planck', 'LCDM_phy_BBAO+Planck+SN','LCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['h','Om'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
plt.title("$\Lambda$CDM", fontsize = 20)
#g.export('Obh2_Om_LCDM_todas.pdf')

roots2 = ['cLCDM_phy_BBAO', 'cLCDM_phy_BBAO+Planck', 'cLCDM_phy_BBAO+Planck+SN','cLCDM_phy_BBAO+Planck+SN+HD']

g2= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g2.plot_2d(roots2, param_pair=['Om','Ok'], filled=True)
g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
plt.title("o$\Lambda$CDM", fontsize = 20)
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in
# Text(0.5,1,'o$\\Lambda$CDM')

# %% [markdown]
# ## Prueba para poner las gráficas juntas.

# %%
roots1 = ['LCDM_phy_BBAO', 'LCDM_phy_BBAO+Planck', 'LCDM_phy_BBAO+Planck+SN','LCDM_phy_BBAO+Planck+SN+HD']
roots2 = ['cLCDM_phy_BBAO', 'cLCDM_phy_BBAO+Planck', 'cLCDM_phy_BBAO+Planck+SN','cLCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSubplotPlotter(chain_dir = dir_name, subplot_size=4)

#Varias graficas.
g.plot_2d([roots1, roots2], param_pair=[['h','Om'],['Om','Ok']], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
#plt.title(["$\Lambda$CDM", "o$\Lambda$CDM"], fontsize = 20)
#g.export('Obh2_Om_LCDM_todas.pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-bbade861a98e> in <module>()
#       5
#       6 #Varias graficas.
# ----> 7 g.plot_2d([roots1, roots2], param_pair=[['h','Om'],['Om','Ok']], filled=True)
#       8 #g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='upper right')
#       9 #plt.title(["$\Lambda$CDM", "o$\Lambda$CDM"], fontsize = 20)
#
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/getdist/getdist/plots.pyc in plot_2d(self, roots, param1, param2, param_pair, shaded, add_legend_proxy, line_offset, proxy_root_exclude, **kwargs)
#    1062             param_pair = param1
#    1063             param1 = None
# -> 1064         param_pair = self.get_param_array(roots[0], param_pair or [param1, param2])
# ...

# %% [markdown]
# ## wCDM

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['wCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['Om','w'], filled=True)
#g.add_legend(['BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='lower left')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0.299, color = 'black', lw = '1') #linea en x
plt.title("wCDM", fontsize = 20)
g.export('Om_w_wCDM_BBAO+Planck+SN+HD.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/wCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in

# %% [markdown]
# ## owCDM

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
#roots = ['owCDM_phy_BBAO', 'owCDM_phy_BBAO+Planck', 'owCDM_phy_BBAO+Planck+SN','owCDM_phy_BBAO+Planck+SN+HD']
roots = ['owCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['w','Ok'], filled=True)
#g.add_legend(['BBAO', 'BBAO+Planck', 'BBAO+Planck+SN','BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='lower left')
#g.add_legend(['BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='lower left')
g.add_y_marker(0, color = 'black', lw= '1') #linea en y
g.add_x_marker(-1, color = 'black', lw = '1') #linea en x
plt.title("owCDM", fontsize = 20)
g.export('w_Ok_owCDM_BBAO+Planck+SN+HD.pdf')
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed no burn in

# %% [markdown]
# ## waCDM (wowaCDM en el paper)

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['waCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['w','wa'], filled=True)
#g.add_legend(['BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='lower left')
g.add_y_marker(0, color = 'black', lw= '1') #linea en y
g.add_x_marker(-1, color = 'black', lw = '1') #linea en x
plt.title("$w_o w_a$CDM", fontsize = 20)
g.export('w_wa_wowaCDM_BBAO+Planck+SN+HD.pdf')

# %% [markdown]
# ## owaCDM (owowaCDM en el paper)

# %%
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['owaCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['w','Ok'], filled=True)
#g.add_legend(['BBAO+Planck+SN+HD'], colored_text=True,  legend_loc='lower left')
g.add_y_marker(0, color = 'black', lw= '1') #linea en y
g.add_x_marker(-1, color = 'black', lw = '1') #linea en x
plt.title("o$w_o w_a$CDM", fontsize = 20)
g.export('w_Ok_owowaCDM_BBAO+Planck+SN+HD.pdf')

# %% [markdown]
# ## En esta parte obtendremos los valores de mejor ajuste para los parámetros de distintos modelos.

# %% [markdown]
# # wCDM BBAO+Planck+SN+HD

# %%
roots = ['wCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples13 = g.sampleAnalyser.samplesForRoot('wCDM_phy_BBAO+Planck+SN+HD')
p13 = samples13.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/wCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples13.likeStats
# Out:
# Best fit sample -log(Like) = 36.565600
# Ln(mean 1/like) = 42.379213
# mean(-Ln(like)) = 38.530618
# -Ln(mean like)  = 37.928491
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# w                  -9.6153300E-01 -1.0754300E+00 -8.6029800E-01 -1.1243200E+00 -8.1879100E-01   w_0
# Om                  3.0324800E-01  2.8315100E-01  3.2205100E-01  2.7505900E-01  3.3032900E-01   \Omega_m
# Obh2                2.2447600E-02  2.1819000E-02  2.3097200E-02  2.1572900E-02  2.3380600E-02   \Omega_bh^2
# h                   6.7725500E-01  6.5570200E-01  7.0182400E-01  6.4710600E-01  7.1231400E-01   h
# DR11LOWZ_like      -8.8423200E-02 -7.8242000E-01 -6.8735000E-10 -1.3240000E+00 -1.5114300E-12   DR11LOWZ
# DR11CMASS_like     -1.3167100E+00 -3.6731500E+00 -7.0261200E-01 -5.4174700E+00 -5.4129000E-01   DR11CMASS
# DR11LyaAuto_like   -2.2648000E+00 -2.6240800E+00 -1.9265000E+00 -2.8360500E+00 -1.8047800E+00   DR11LyaAuto
# ...

# %%
#Da la desviacion estandar
samples13.std(p13.Om), samples13.std(p13.Obh2), samples13.std(p13.h), samples13.std(p13.w)
# Out:
# (0.009136193485738842,
#  0.0002993135462206573,
#  0.010773999189102804,
#  0.050369798753588976)

# %% [markdown]
# # owCDM BBAO+Planck+SN+HD

# %%
roots = ['owCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples14 = g.sampleAnalyser.samplesForRoot('owCDM_phy_BBAO+Planck+SN+HD')
p14 = samples14.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples14.likeStats
# Out:
# Best fit sample -log(Like) = 35.749300
# Ln(mean 1/like) = 43.029429
# mean(-Ln(like)) = 38.241952
# -Ln(mean like)  = 37.463462
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.9951800E-01  2.7734700E-01  3.2151400E-01  2.6889900E-01  3.2986100E-01   \Omega_m
# Obh2                2.2656300E-02  2.1867100E-02  2.3473700E-02  2.1572400E-02  2.3782300E-02   \Omega_bh^2
# h                   6.7568200E-01  6.5316500E-01  7.0289600E-01  6.4401900E-01  7.1299400E-01   h
# w                  -9.7635600E-01 -1.1044200E+00 -8.6509300E-01 -1.1564900E+00 -8.1858400E-01   w_0
# Ok                 -3.6260700E-03 -1.0731200E-02  3.4094500E-03 -1.3252500E-02  6.2369700E-03   \Omega_k
# DR11LOWZ_like      -1.6863900E-01 -1.2933000E+00 -1.7025900E-09 -1.9517600E+00 -1.0518400E-09   DR11LOWZ
# DR11CMASS_like     -1.2668500E+00 -3.4748900E+00 -7.0142600E-01 -5.3149200E+00 -5.3934400E-01   DR11CMASS
# ...

# %%
#Da la desviacion estandar
samples14.std(p14.Om), samples14.std(p14.Obh2), samples14.std(p14.h), samples14.std(p14.w), samples14.std(p14.Ok)
# Out:
# (0.009419275288486162,
#  0.00034710431226336397,
#  0.010721352231061921,
#  0.05181982769570225,
#  0.0030045162497530265)

# %% [markdown]
# # wowaCDM BBAO+Planck+SN+HD

# %%
roots = ['waCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples15 = g.sampleAnalyser.samplesForRoot('waCDM_phy_BBAO+Planck+SN+HD')
p15 = samples15.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/waCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples15.likeStats
# Out:
# Best fit sample -log(Like) = 36.404200
# mean(-Ln(like)) = 38.894207
# -Ln(mean like)  = 38.112573
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0668000E-01  2.8119800E-01  3.3164300E-01  2.7173800E-01  3.4207800E-01   \Omega_m
# Obh2                2.2389300E-02  2.1619500E-02  2.3165000E-02  2.1352500E-02  2.3453500E-02   \Omega_bh^2
# h                   6.7418600E-01  6.5152700E-01  7.0376200E-01  6.4256800E-01  7.1382300E-01   h
# w                  -9.1191700E-01 -1.1445800E+00 -6.6289800E-01 -1.2262400E+00 -5.6153700E-01   w_0
# wa                 -1.6917800E-01 -1.3365300E+00  5.7887800E-01 -1.8859600E+00  8.3539300E-01   w_a
# DR11LOWZ_like      -6.6897800E-02 -8.4945500E-01 -2.5392500E-10 -1.4263200E+00 -1.5547100E-10   DR11LOWZ
# DR11CMASS_like     -1.3871500E+00 -4.8677200E+00 -6.4691400E-01 -7.0034700E+00 -4.9869400E-01   DR11CMASS
# ...

# %%
#Da la desviacion estandar
samples15.std(p15.Om), samples15.std(p15.Obh2), samples15.std(p15.h), samples15.std(p15.w), samples15.std(p15.wa)
# Out:
# (0.010777894954989967,
#  0.00033262998544882863,
#  0.011110599528141134,
#  0.10480894458930645,
#  0.4140161814780679)

# %% [markdown]
# # owowaCDM BBAO+Planck+SN+HD

# %%
roots = ['owaCDM_phy_BBAO+Planck+SN+HD']

g = plots.getSinglePlotter(chain_dir= dir_name, analysis_settings={'smooth_scale_1D': -1, 'ignore_rows': 0.3} )
samples16 = g.sampleAnalyser.samplesForRoot('owaCDM_phy_BBAO+Planck+SN+HD')
p16 = samples16.getParams()
# Out:
# /home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/owaCDM_phy_BBAO+Planck+SN+HD_1.txt
# Removed 0.3 as burn in

# %%
#Datos de mejor ajuste.
print samples16.likeStats
# Out:
# Best fit sample -log(Like) = 34.840500
# Ln(mean 1/like) = 42.775734
# mean(-Ln(like)) = 37.800551
# -Ln(mean like)  = 36.879901
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0619100E-01  2.7898800E-01  3.3330400E-01  2.6935700E-01  3.4275700E-01   \Omega_m
# Obh2                2.2633800E-02  2.1723300E-02  2.3446900E-02  2.1454500E-02  2.3761400E-02   \Omega_bh^2
# h                   6.7003400E-01  6.4449400E-01  7.0058800E-01  6.3548700E-01  7.1151200E-01   h
# w                  -8.6309100E-01 -1.1166300E+00 -5.5023400E-01 -1.2013400E+00 -4.7687000E-01   w_0
# wa                 -5.2863600E-01 -1.9979700E+00  4.0021300E-01 -1.9998800E+00  7.6130700E-01   w_a
# Ok                 -5.9608800E-03 -1.4167800E-02  2.4703200E-03 -1.6818500E-02  5.5716000E-03   \Omega_k
# DR11LOWZ_like      -1.4339900E-01 -1.2586700E+00 -1.0837300E-11 -1.8018300E+00 -1.0837300E-11   DR11LOWZ
# ...

# %%
#Da la desviacion estandar
samples16.std(p16.Om), samples16.std(p16.Obh2), samples16.std(p16.h), samples16.std(p16.w), samples16.std(p16.wa),samples16.std(p16.Ok)
# Out:
# (0.010763838500255883,
#  0.0003410645923368654,
#  0.011304843722743887,
#  0.1134803407200201,
#  0.5150364981971012,
#  0.0033424220424508886)

# %% [markdown]
# ## En esta sección vamos a hacer la prueba para hacer la gráfica que se necesita para el paper de bayesiana en el que se muestran las curvas de confianza con la cadena que se acerca a los valores de mejor ajuste.

# %% [markdown]
# ### Vamos a probar haciendo la línea.

# %%
cols = np.loadtxt('/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN+HD_1.txt', dtype=str)

i = 0
for aux in cols:
    i = i+1
    mod = i%500
    if mod == 0:
       print(i)
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500

# %%
cols = np.loadtxt('/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN+HD_1.txt', dtype=str)

i = 0
for aux in cols:
    mod = i%1000
    if mod == 0:
        x = cols[i,4]
        y = cols[i,2]
        print(x,y)
    i = i+1    
#plt.plot(x,y)
print(x,y)
# Out:
# ('0.692087', '0.287511')
# ('0.689732', '0.296856')
# ('0.677389', '0.309726')
# ('0.680198', '0.303864')
# ('0.701582', '0.281283')
# ('0.686021', '0.297976')
# ('0.684659', '0.295013')
# ('0.693758', '0.284431')
# ('0.683426', '0.301781')
# ('0.688443', '0.292936')
# ('0.688443', '0.292936')

# %%
#Este es el weno. LambdaCDM
cols = np.loadtxt('/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN+HD_1.txt', dtype=float)
#x,y son los arreglos donde se guarda h y Om
x = []
y = []
z = []
w = []
j = 0
i = 0
#Para las lineas.
for aux in cols:
    mod = i%10000
    if mod == 0:
        aux1 = cols[i,4]
        aux2 = cols[i,2]
        #print(aux1)
        x.append(aux1)
        y.append(aux2)
        #print(x[j],y[j])
        j = j+1
        #print(x,y)
    aux1 = 0    
    aux2 = 0
    i = i+1   
#Para los puntos.
j = 0
i = 0
aux1 = 0
aux2 = 0 
aux = 0
for aux in cols:
    mod = i%1000
    if mod == 0:
        aux1 = cols[i,4]
        aux2 = cols[i,2]
        #print(aux1)
        z.append(aux1)
        w.append(aux2)
        #print(x[j],y[j])
        j = j+1
        #print(x,y)
    aux1 = 0    
    aux2 = 0
    i = i+1    
print(len(x))
#for a in range(len(x2)):
#        print(x2[a])
plt.plot(x,y,'ko-')
plt.plot(z,w, 'r.')
# Out:
# 10

# %%
#Vamos a imprimir las regiones de confianza sin relleno con la curva de arriba.
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['LCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['h','Om'], filled=False, colors=['red'])#Con el filled=False se quita el relleno
g.add_legend(['BBAO+Planck+SN+HD'], legend_loc='lower left')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
plt.plot(x,y,'ko-')
plt.plot(z,w, 'b.')
#
plt.title("$\Lambda$CDM", fontsize = 20)
#g.export('h_Om_LCDM_BBAO+Planck+SN+HD.pdf')
g.export('h_Om_LCDM_cadena_confianza.pdf')

# %%
#Este es el weno. LambdaCDM con curvatura
cols = np.loadtxt('/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/cLCDM_phy_BBAO+Planck+SN+HD_1.txt', dtype=float)
#x,y son los arreglos donde se guarda h y Om
x = []
y = []
z = []
w = []
j = 0
i = 0
#Para las lineas.
for aux in cols:
    mod = i%5000
    if mod == 0:
        aux1 = cols[i,4]
        aux2 = cols[i,2]
        #print(aux1)
        x.append(aux1)
        y.append(aux2)
        #print(x[j],y[j])
        j = j+1
        #print(x,y)
    aux1 = 0    
    aux2 = 0
    i = i+1   
#Para los puntos.
j = 0
i = 0
aux1 = 0
aux2 = 0 
aux = 0
for aux in cols:
    mod = i%500
    if mod == 0:
        aux1 = cols[i,4]
        aux2 = cols[i,2]
        #print(aux1)
        z.append(aux1)
        w.append(aux2)
        #print(x[j],y[j])
        j = j+1
        #print(x,y)
    aux1 = 0    
    aux2 = 0
    i = i+1    
print(len(x))
#for a in range(len(x2)):
#        print(x2[a])
plt.plot(x,y,'ko-')
plt.plot(z,w, 'r.')
# Out:
# 20

# %%
#Vamos a imprimir las regiones de confianza sin relleno con la curva de arriba.
#g = planckStyle.getSinglePlotter(chain_dir = dir_name)
roots = ['cLCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)

#Varias graficas.
g.plot_2d(roots, param_pair=['h','Om'], filled=False, colors=['red'])#Con el filled=False se quita el relleno
g.add_legend(['BBAO+Planck+SN+HD'], legend_loc='lower left')
g.add_y_marker(-1, color = 'black', lw= '1') #linea en y
g.add_x_marker(0, color = 'black', lw = '1') #linea en x
plt.plot(x,y,'k.-')
plt.plot(z,w, 'b.')
#
plt.title("o$\Lambda$CDM", fontsize = 20)
g.export('h_Om_oLCDM_cadena_confianza.pdf')

# %% [markdown]
# ## Se va a graficar la cadena de h para $\Lambda$CDM.

# %%
roots = ['cLCDM_phy_BBAO+Planck+SN+HD']

g= plots.getSinglePlotter(chain_dir = dir_name)
#Este es el weno. LambdaCDM
cols = np.loadtxt('/home/osbuster/Documentos/Prueba2_SMC/SimpleMC-master/chains/LCDM_phy_BBAO+Planck+SN+HD_2.txt', dtype=float)
#x -> se guarda h.
x = []
y = []
i = 0
j = 1
#Para las lineas.
for aux in cols:
    if i <= 9000:
        aux1 = cols[i,4]
    #print(aux1)
        x.append(aux1)
        y.append(j)
    #print(x)
        aux1 = 0    
        i = i+1  
        j = j+1
#plt.hist(x,histtype = 'step')
plt.plot(y,x,'k+')
plt.xlabel('Number of steps')
plt.ylabel('h')
plt.title('$\Lambda$CDM', fontsize = 20)
#plt.savefig('cadena_LCDM_h.pdf')
g.export('cadena_LCDM_h.pdf')
